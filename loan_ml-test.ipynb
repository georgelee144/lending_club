# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('lending_club_ml.csv')
df.drop(['id'], inplace=True, axis=1)

# %%
# creating columns for features that had more than 2 outcomes
# I have decided to use subgrade and not grade as these are suppose to be similar features but, subgrade is more granular

df = pd.concat([df, pd.get_dummies(
    df.sub_grade, prefix='sub_grade', drop_first=True)], axis=1)
df = pd.concat([df, pd.get_dummies(df.home_ownership,
                                   prefix='home_ownership', drop_first=True)], axis=1)
df = pd.concat([df, pd.get_dummies(df.verification_status,
                                   prefix='verification_status', drop_first=True)], axis=1)
df = pd.concat(
    [df, pd.get_dummies(df.purpose, prefix='purpose', drop_first=True)], axis=1)
df = pd.concat([df, pd.get_dummies(df.verification_status_joint,
                                   prefix='verification_status_joint', drop_first=True)], axis=1)

df.drop(columns=['sub_grade', 'home_ownership', 'verification_status',
                 'purpose', 'verification_status_joint'], inplace=True)


# conversions for features that only had 2 outcomes

df.disbursement_method = df.disbursement_method.apply(
    lambda disburstment: 1 if disburstment == 'Cash' else 0)

df.application_type = df.application_type.apply(
    lambda app_type: 1 if app_type == 'Individual' else 0)

# %%
"""# if borrower is an indivudal then their secondary features are filled with their single counterpart

sec_list = ['sec_app_fico_range_low', 'sec_app_fico_range_high', 'sec_app_inq_last_6mths', 'sec_app_mort_acc',
            'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il','sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths',
            'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog']
joint_list = ['dti_joint', 'revol_bal_joint', 'annual_inc_joint']

for secondary in sec_list:
    df.loc[df.application_type == 1,secondary] = df.loc[df.application_type == 1][secondary[8:]]


for joint in joint_list:
    df.loc[df.application_type == 1,joint] = df.loc[df.application_type == 1][joint[:len(joint)-6]]

df.info()"""
# Out:
# "# if borrower is an indivudal then their secondary features are filled with their single counterpart\n\nsec_list = ['sec_app_fico_range_low', 'sec_app_fico_range_high', 'sec_app_inq_last_6mths', 'sec_app_mort_acc',\n            'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il','sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths',\n            'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog']\njoint_list = ['dti_joint', 'revol_bal_joint', 'annual_inc_joint']\n\nfor secondary in sec_list:\n    df.loc[df.application_type == 1,secondary] = df.loc[df.application_type == 1][secondary[8:]]\n\n\nfor joint in joint_list:\n    df.loc[df.application_type == 1,joint] = df.loc[df.application_type == 1][joint[:len(joint)-6]]\n\ndf.info()"

# %%
#fill all nans with 0
df.fillna(0, inplace=True)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score


def scoring(clf, x, y):
    
    #Baseline
    print('Loan passing rate:', np.mean(y))
    print('Balanced loan passing rate:', np.average(y, weights=x['loan_amnt']))
    print('\n')
    
    
    print('score: ', clf.score(x, y))
    # score adjusted for loan amount
    print('balanced_accuracy_score: ', balanced_accuracy_score(
        y, clf.predict(x), sample_weight=x['loan_amnt']))

    print(confusion_matrix(y, clf.predict(x)))
    
    print('F1 score: ', f1_score(y, clf.predict(x)))
    
    print('precision_score: ', precision_score(y, clf.predict(x)))

    # score adjusted for loan amount
    print('average_precision_score: ', average_precision_score(
        y, clf.predict(x), average='weighted', sample_weight=x['loan_amnt']))
    
    print('recall_score: ', recall_score(y, clf.predict(x)))

    print('roc: ', roc_auc_score(y, clf.predict_proba(x)[:, 1]))

    # score adjusted for loan amount
    print('roc_weighted: ', roc_auc_score(y, clf.predict_proba(x)[
          :, 1], average='weighted', sample_weight=x['loan_amnt']))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X = df.drop(['grade','loan_status'], axis=1)
y = df.loan_status

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)



rf_best = RandomForestClassifier(criterion= 'entropy', n_estimators= 101)
rf_best.fit(X_train, y_train)
    
print('RANDOM FOREST')
scoring(rf_best, X_test, y_test)
# Out:
# RANDOM FOREST
# Loan passing rate: 0.8009672589365736
# Balanced loan passing rate: 0.7855872316459166
#
#
# score:  0.9414312347245161
# balanced_accuracy_score:  0.8596973398785499
# [[107936  41741]
#  [  2304 600041]]
# F1 score:  0.9645976656723951
# precision_score:  0.9349607810751938
# average_precision_score:  0.9289922760237548
# recall_score:  0.9961749495720891
# roc:  0.9644580392774568
# roc_weighted:  0.965244315949617

# %%
scoring(rf_best, X_train, y_train)
# Out:
# Loan passing rate: 0.8015205879469954
# Balanced loan passing rate: 0.7865164321952773
#
#
# score:  0.9999971505360412
# balanced_accuracy_score:  0.9999897655383001
# [[ 348270       5]
#  [      0 1406441]]
# F1 score:  0.9999982224668108
# precision_score:  0.9999964449399408
# average_precision_score:  0.9999944441662757
# recall_score:  1.0
# roc:  0.9999999999999999
# roc_weighted:  0.9999999999999999

# %% [markdown]
# # Testing based off of certain features
# Here will be testing our classifier, that was trained and test on the general population with global averages to fill the nans, on certain sub-groups of the population and to see if we need to fill nans with local averages.

# %%
#train and test the subsection of the data

def ml_test(dataframe):
    dataframe.fillna(0,inplace=True)
    
    X = dataframe.drop(['grade','loan_status'], axis=1)
    y = dataframe.loan_status

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
    #first print out the test scores on our main classifer on subsection
    print('MAIN CLASSIFER')
    scoring(rf_best, X_test, y_test)
    
    #trains random forest model on subsection then prints out scores
    print('\n')
    print('RETRAINED CLASSIFER')
    rf = RandomForestClassifier(criterion= 'entropy', n_estimators= 101)
    rf.fit(X_train, y_train)
    scoring(rf, X_test, y_test)

# %% [markdown]
# Individual verse joint: in our EDA joint borrowers failed in higher rates and had wide differences between their single and joint/secondary features.

# %%
ml_test(df.loc[df.application_type == 1])
# Out:
# MAIN CLASSIFER
# Loan passing rate: 0.8018762389397847
# Balanced loan passing rate: 0.7866714294905874
#
#
# score:  0.976385082389074
# balanced_accuracy_score:  0.9432222459588948
# [[130203  16618]
#  [   882 593354]]
# F1 score:  0.9854676268551613
# precision_score:  0.9727561265107251
# average_precision_score:  0.970208747116037
# recall_score:  0.9985157412206598
# roc:  0.9922711138650856
# roc_weighted:  0.9925060586911842
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8018762389397847
# Balanced loan passing rate: 0.7866714294905874
#
#
# score:  0.9412649769181048
# balanced_accuracy_score:  0.8591762956857232
# [[105637  41184]
#  [  2342 591894]]
# F1 score:  0.9645355630262509
# precision_score:  0.9349464047084246
# average_precision_score:  0.9291758985403014
# recall_score:  0.9960588049192577
# roc:  0.9637510018663393
# roc_weighted:  0.964695795792294

# %%
ml_test(df.loc[df.application_type == 0])
# Out:
# MAIN CLASSIFER
# Loan passing rate: 0.7680802553579571
# Balanced loan passing rate: 0.7633904760778214
#
#
# score:  0.9800273597811218
# balanced_accuracy_score:  0.9602156679297928
# [[2346  197]
#  [  22 8400]]
# F1 score:  0.9871320289088665
# precision_score:  0.9770850296615098
# average_precision_score:  0.9760969378967801
# recall_score:  0.9973877938731893
# roc:  0.9968989098734258
# roc_weighted:  0.9971694819253112
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7680802553579571
# Balanced loan passing rate: 0.7633904760778214
#
#
# score:  0.9261285909712722
# balanced_accuracy_score:  0.8413188780617371
# [[1763  780]
#  [  30 8392]]
# F1 score:  0.9539615778106173
# precision_score:  0.914958569559529
# average_precision_score:  0.9105429772872695
# recall_score:  0.9964379007361672
# roc:  0.9629353509566587
# roc_weighted:  0.9622769263178165

# %% [markdown]
# The Global classifier has outperformed the locally trained version.

# %% [markdown]
# ML for different grades

# %%
grades = set(df.grade)

for loan_grade in sorted(grades):
    print(loan_grade)
    ml_test(df.loc[df.grade==loan_grade])
    print('\n')
# Out:
# A
# MAIN CLASSIFER
# Loan passing rate: 0.9405104807551982
# Balanced loan passing rate: 0.9413940416432522
#
#
# score:  0.9946156032291018
# balanced_accuracy_score:  0.9570227584450608
# [[  7044    701]
#  [     0 122446]]
# F1 score:  0.9971456841196614
# precision_score:  0.9943076161010824
# average_precision_score:  0.9946774331480273
# recall_score:  1.0
# roc:  0.9926290918592253
# roc_weighted:  0.992649224622702
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.9405104807551982
# Balanced loan passing rate: 0.9413940416432522
#
#
# score:  0.9826639322226575
# balanced_accuracy_score:  0.8520034887242486
# [[  5488   2257]
#  [     0 122446]]
# F1 score:  0.9908678570417035
# precision_score:  0.9819009967683215
# average_precision_score:  0.9819065265606292
# recall_score:  1.0
# roc:  0.9477328987288551
# roc_weighted:  0.9464595150660863
#
#
# B
# MAIN CLASSIFER
# Loan passing rate: 0.8673473571985074
# Balanced loan passing rate: 0.8650654540003315
#
#
# score:  0.9879580650893236
# balanced_accuracy_score:  0.9543750129887569
# [[ 26472   2643]
#  [     0 190368]]
# F1 score:  0.9931060386719147
# precision_score:  0.9863064799415577
# average_precision_score:  0.9859664014596835
# recall_score:  1.0
# roc:  0.9947178603062202
# roc_weighted:  0.9946531494694633
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8673473571985074
# Balanced loan passing rate: 0.8650654540003315
#
#
# score:  0.959882997772037
# balanced_accuracy_score:  0.8500099954660674
# [[ 20312   8803]
#  [     2 190366]]
# F1 score:  0.97739624220549
# precision_score:  0.9558013546284814
# average_precision_score:  0.9553001678029355
# recall_score:  0.9999894940326105
# roc:  0.9551669482475217
# roc_weighted:  0.9556555739197636
#
#
# C
# MAIN CLASSIFER
# Loan passing rate: 0.7772935382135309
# Balanced loan passing rate: 0.7696991390065671
#
#
# score:  0.9800790091521278
# balanced_accuracy_score:  0.9553250248742031
# [[ 43301   4223]
#  [    28 165841]]
# F1 score:  0.9873456909562324
# precision_score:  0.9751681719823125
# average_precision_score:  0.9739731011548294
# recall_score:  0.9998311920853203
# roc:  0.9958647411822299
# roc_weighted:  0.9958492847192261
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7772935382135309
# Balanced loan passing rate: 0.7696991390065671
#
#
# score:  0.9333623877071882
# balanced_accuracy_score:  0.8522804853956161
# [[ 33400  14124]
#  [    96 165773]]
# F1 score:  0.9588739205127167
# precision_score:  0.9214884072552627
# average_precision_score:  0.9187995429400192
# recall_score:  0.9994212300068126
# roc:  0.961584586850933
# roc_weighted:  0.9616810481291411
#
#
# D
# MAIN CLASSIFER
# Loan passing rate: 0.6985549107182656
# Balanced loan passing rate: 0.684318232759796
#
#
# score:  0.9731486186515471
# balanced_accuracy_score:  0.9568431367871786
# [[31016  2798]
#  [  214 78145]]
# F1 score:  0.9810925161014927
# precision_score:  0.9654324648209234
# average_precision_score:  0.9620573387686693
# recall_score:  0.99726897995125
# roc:  0.9964719382802141
# roc_weighted:  0.996477584840475
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.6985549107182656
# Balanced loan passing rate: 0.684318232759796
#
#
# score:  0.9111550907972507
# balanced_accuracy_score:  0.8577668306674076
# [[24372  9442]
#  [  524 77835]]
# F1 score:  0.9398319205969716
# precision_score:  0.8918157131890417
# average_precision_score:  0.8844179887559284
# recall_score:  0.9933128294133412
# roc:  0.9635270844290692
# roc_weighted:  0.9642432778606229
#
#
# E
# MAIN CLASSIFER
# Loan passing rate: 0.6156433188035473
# Balanced loan passing rate: 0.6043316083087944
#
#
# score:  0.9665752292199008
# balanced_accuracy_score:  0.9577344781314219
# [[18930  1527]
#  [  252 32515]]
# F1 score:  0.9733718510979059
# precision_score:  0.9551436460842488
# average_precision_score:  0.9491816671328064
# recall_score:  0.9923093356120487
# roc:  0.9965177734722467
# roc_weighted:  0.9963503209607368
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.6156433188035473
# Balanced loan passing rate: 0.6043316083087944
#
#
# score:  0.8880580189388246
# balanced_accuracy_score:  0.8621611112027612
# [[15587  4870]
#  [ 1088 31679]]
# F1 score:  0.9140458191470945
# precision_score:  0.8667542203617062
# average_precision_score:  0.8505444712626209
# recall_score:  0.966795861690115
# roc:  0.9645402966424482
# roc_weighted:  0.963372645954447
#
#
# F
# MAIN CLASSIFER
# Loan passing rate: 0.549331012727075
# Balanced loan passing rate: 0.5378723846276439
#
#
# score:  0.9633960622212553
# balanced_accuracy_score:  0.9606479721542514
# [[7778  508]
#  [ 165 9935]]
# F1 score:  0.9672394489607165
# precision_score:  0.9513549746241502
# average_precision_score:  0.9416138530875536
# recall_score:  0.9836633663366336
# roc:  0.996665913875964
# roc_weighted:  0.996591899732738
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.549331012727075
# Balanced loan passing rate: 0.5378723846276439
#
#
# score:  0.877297944087893
# balanced_accuracy_score:  0.8692759176825118
# [[6858 1428]
#  [ 828 9272]]
# F1 score:  0.8915384615384615
# precision_score:  0.8665420560747663
# average_precision_score:  0.8303520966398266
# recall_score:  0.9180198019801981
# roc:  0.9650617407866783
# roc_weighted:  0.9632133976504548
#
#
# G
# MAIN CLASSIFER
# Loan passing rate: 0.49284885968303055
# Balanced loan passing rate: 0.4956165657835817
#
#
# score:  0.9644375724777735
# balanced_accuracy_score:  0.9658715703337204
# [[2495  129]
#  [  55 2495]]
# F1 score:  0.9644375724777735
# precision_score:  0.9508384146341463
# average_precision_score:  0.9435671022145894
# recall_score:  0.9784313725490196
# roc:  0.9970471664275466
# roc_weighted:  0.9972476084445535
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.49284885968303055
# Balanced loan passing rate: 0.4956165657835817
#
#
# score:  0.8705063780440665
# balanced_accuracy_score:  0.8682146861853439
# [[2276  348]
#  [ 322 2228]]
# F1 score:  0.869293796332423
# precision_score:  0.8649068322981367
# average_precision_score:  0.8134410504545342
# recall_score:  0.8737254901960785
# roc:  0.9615928383548541
# roc_weighted:  0.9606040578015039

# %% [markdown]
# The Global classifier has outperformed the locally trained version.

# %% [markdown]
# ML for different loan sizes

# %%
for decile in np.arange(1,11):
    print((decile-1)*10,decile*10)
    
    ml_test(df.loc[(df.loan_amnt > np.percentile(df.loan_amnt,(decile-1)*10)) & 
                   (df.loan_amnt<np.percentile(df.loan_amnt,decile*10))])
    print('\n')
# Out:
# 0 10
# MAIN CLASSIFER
# Loan passing rate: 0.8456880009798451
# Balanced loan passing rate: 0.8423225500026952
#
#
# score:  0.985996380016603
# balanced_accuracy_score:  0.9552806926480657
# [[10321  1018]
#  [   11 62131]]
# F1 score:  0.9917871195856046
# precision_score:  0.983879396348319
# average_precision_score:  0.9835388338289567
# recall_score:  0.9998229860641756
# roc:  0.9956453740142861
# roc_weighted:  0.9955258299792639
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8456880009798451
# Balanced loan passing rate: 0.8423225500026952
#
#
# score:  0.9557164437065364
# balanced_accuracy_score:  0.8572687890872621
# [[ 8099  3240]
#  [   14 62128]]
# F1 score:  0.974480432907223
# precision_score:  0.9504344633459797
# average_precision_score:  0.9492773441418482
# recall_score:  0.9997747095362235
# roc:  0.9622828843091134
# roc_weighted:  0.9622485592376738
#
#
# 10 20
# MAIN CLASSIFER
# Loan passing rate: 0.8402740327960533
# Balanced loan passing rate: 0.8404687232746312
#
#
# score:  0.984780394271676
# balanced_accuracy_score:  0.9527586862519227
# [[ 7242   755]
#  [    7 42063]]
# F1 score:  0.9910234662143059
# precision_score:  0.9823672287355785
# average_precision_score:  0.9823859416537345
# recall_score:  0.9998336106489185
# roc:  0.994832284830843
# roc_weighted:  0.9948375865446552
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8402740327960533
# Balanced loan passing rate: 0.8404687232746312
#
#
# score:  0.9512653044919808
# balanced_accuracy_score:  0.8486686225911821
# [[ 5579  2418]
#  [   22 42048]]
# F1 score:  0.9718036424147176
# precision_score:  0.9456213736337876
# average_precision_score:  0.9456787760720419
# recall_score:  0.9994770620394581
# roc:  0.9583164729083842
# roc_weighted:  0.9582742657071363
#
#
# 20 30
# MAIN CLASSIFER
# Loan passing rate: 0.8309950443577244
# Balanced loan passing rate: 0.8307076537011601
#
#
# score:  0.9847819922492135
# balanced_accuracy_score:  0.9552643396922005
# [[11399  1117]
#  [   10 61531]]
# F1 score:  0.9909251221927868
# precision_score:  0.9821702209168689
# average_precision_score:  0.9820974284817952
# recall_score:  0.9998375067028485
# roc:  0.9951026920766717
# roc_weighted:  0.9950950575700832
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8309950443577244
# Balanced loan passing rate: 0.8307076537011601
#
#
# score:  0.9493498251346936
# balanced_accuracy_score:  0.8513820556889458
# [[ 8803  3713]
#  [   38 61503]]
# F1 score:  0.9704079459122573
# precision_score:  0.9430661187438666
# average_precision_score:  0.9428943766551022
# recall_score:  0.9993825254708243
# roc:  0.9582540516384588
# roc_weighted:  0.9583045794679859
#
#
# 30 40
# MAIN CLASSIFER
# Loan passing rate: 0.8246477617264134
# Balanced loan passing rate: 0.8243078159533855
#
#
# score:  0.9849117174959872
# balanced_accuracy_score:  0.9572246710687387
# [[ 4495   421]
#  [    2 23117]]
# F1 score:  0.9909338362946611
# precision_score:  0.9821140283796415
# average_precision_score:  0.9820949961476562
# recall_score:  0.9999134910679528
# roc:  0.9960735221745656
# roc_weighted:  0.9960860509294056
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8246477617264134
# Balanced loan passing rate: 0.8243078159533855
#
#
# score:  0.9457820581416087
# balanced_accuracy_score:  0.8480283867212985
# [[ 3428  1488]
#  [   32 23087]]
# F1 score:  0.968130163123244
# precision_score:  0.9394506612410987
# average_precision_score:  0.9391818643758092
# recall_score:  0.9986158570872442
# roc:  0.9562862940252772
# roc_weighted:  0.9563275775141765
#
#
# 40 50
# MAIN CLASSIFER
# Loan passing rate: 0.7700934579439253
# Balanced loan passing rate: 0.769898129472552
#
#
# score:  0.9808332013305877
# balanced_accuracy_score:  0.9606711422092877
# [[ 6701   556]
#  [   49 24259]]
# F1 score:  0.9876839769558049
# precision_score:  0.9775941970582309
# average_precision_score:  0.9771448895077176
# recall_score:  0.997984202731611
# roc:  0.995534952333846
# roc_weighted:  0.9955592314514957
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7700934579439253
# Balanced loan passing rate: 0.769898129472552
#
#
# score:  0.9322033898305084
# balanced_accuracy_score:  0.8617020527087571
# [[ 5309  1948]
#  [  192 24116]]
# F1 score:  0.957516080362106
# precision_score:  0.9252608962553714
# average_precision_score:  0.9238911984347646
# recall_score:  0.9921013658054961
# roc:  0.9636295679426506
# roc_weighted:  0.9635683537150368
#
#
# 50 60
# MAIN CLASSIFER
# Loan passing rate: 0.7779965593715672
# Balanced loan passing rate: 0.7779150376575796
#
#
# score:  0.9796671295624598
# balanced_accuracy_score:  0.9571543854930041
# [[ 9817   894]
#  [   87 37449]]
# F1 score:  0.9870715217649152
# precision_score:  0.976684140521086
# average_precision_score:  0.97623795497218
# recall_score:  0.9976822250639387
# roc:  0.9959004481891639
# roc_weighted:  0.9959211497738528
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7779965593715672
# Balanced loan passing rate: 0.7779150376575796
#
#
# score:  0.9380894148858996
# balanced_accuracy_score:  0.8695016622004715
# [[ 7984  2727]
#  [  260 37276]]
# F1 score:  0.9614774500573905
# precision_score:  0.9318301127415444
# average_precision_score:  0.9308639822341892
# recall_score:  0.993073316283035
# roc:  0.969351990165873
# roc_weighted:  0.9694985640995644
#
#
# 60 70
# MAIN CLASSIFER
# Loan passing rate: 0.7649989444796285
# Balanced loan passing rate: 0.7648301164890858
#
#
# score:  0.979902892125818
# balanced_accuracy_score:  0.960226098755657
# [[10277   855]
#  [   97 36141]]
# F1 score:  0.98700057350411
# precision_score:  0.9768893934479403
# average_precision_score:  0.9762829442831538
# recall_score:  0.9973232518350902
# roc:  0.9963868929503211
# roc_weighted:  0.9963937403474189
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7649989444796285
# Balanced loan passing rate: 0.7648301164890858
#
#
# score:  0.9325100274435296
# balanced_accuracy_score:  0.8642810421014681
# [[ 8189  2943]
#  [  254 35984]]
# F1 score:  0.9574669061398257
# precision_score:  0.9243969481336861
# average_precision_score:  0.9231981884931854
# recall_score:  0.9929907831558032
# roc:  0.9674670155347199
# roc_weighted:  0.9674463851801717
#
#
# 70 80
# MAIN CLASSIFER
# Loan passing rate: 0.7735375221587552
# Balanced loan passing rate: 0.7739097135273253
#
#
# score:  0.9798273258485982
# balanced_accuracy_score:  0.9577039278645251
# [[12660  1137]
#  [   92 47035]]
# F1 score:  0.9871037471536952
# precision_score:  0.9763970771402475
# average_precision_score:  0.9759861317195212
# recall_score:  0.9980478282088824
# roc:  0.995872412807445
# roc_weighted:  0.9958615857737229
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7735375221587552
# Balanced loan passing rate: 0.7739097135273253
#
#
# score:  0.9329656621364323
# balanced_accuracy_score:  0.8630465574820265
# [[10149  3648]
#  [  436 46691]]
# F1 score:  0.958098208606078
# precision_score:  0.9275313375315362
# average_precision_score:  0.9261870318589579
# recall_score:  0.9907484032507904
# roc:  0.9660610346989413
# roc_weighted:  0.9660835413969053
#
#
# 80 90
# MAIN CLASSIFER
# Loan passing rate: 0.7722949285584592
# Balanced loan passing rate: 0.7724105678601824
#
#
# score:  0.9791192368395324
# balanced_accuracy_score:  0.9570930533226079
# [[14940  1363]
#  [  132 55162]]
# F1 score:  0.9866301791287706
# precision_score:  0.9758867757629368
# average_precision_score:  0.9754658962289507
# recall_score:  0.9976127608782146
# roc:  0.9956434774079711
# roc_weighted:  0.9956143438953744
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7722949285584592
# Balanced loan passing rate: 0.7724105678601824
#
#
# score:  0.932650809391455
# balanced_accuracy_score:  0.8613795286352657
# [[11909  4394]
#  [  428 54866]]
# F1 score:  0.957906314925712
# precision_score:  0.9258521768477894
# average_precision_score:  0.9247137908318079
# recall_score:  0.9922595579990596
# roc:  0.9668003342611332
# roc_weighted:  0.9667804496722345
#
#
# 90 100
# MAIN CLASSIFER
# Loan passing rate: 0.7571632205262905
# Balanced loan passing rate: 0.7572959629998549
#
#
# score:  0.9788266572705286
# balanced_accuracy_score:  0.9577968006562231
# [[13900  1262]
#  [   60 47215]]
# F1 score:  0.9861934998746763
# precision_score:  0.9739670359139385
# average_precision_score:  0.9737388965456052
# recall_score:  0.9987308302485457
# roc:  0.9959334062563238
# roc_weighted:  0.9959596554502054
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7571632205262905
# Balanced loan passing rate: 0.7572959629998549
#
#
# score:  0.9289203517145282
# balanced_accuracy_score:  0.8601616480273586
# [[11022  4140]
#  [  298 46977]]
# F1 score:  0.9548947068867387
# precision_score:  0.9190093315335407
# average_precision_score:  0.9179552132816406
# recall_score:  0.9936964569011105
# roc:  0.9644082498824087
# roc_weighted:  0.9643877019699697

# %% [markdown]
# The Global classifier has outperformed the locally trained version.

# %% [markdown]
# Annual Income by decile

# %%
for decile in np.arange(1,11):
    print((decile-1)*10,decile*10)
    
    ml_test(df.loc[(df.annual_inc > np.percentile(df.annual_inc,(decile-1)*10)) & 
                   (df.annual_inc<np.percentile(df.annual_inc,decile*10))])
    print('\n')
# Out:
# 0 10
# MAIN CLASSIFER
# Loan passing rate: 0.7586561440560218
# Balanced loan passing rate: 0.7413021730605859
#
#
# score:  0.9791585616628689
# balanced_accuracy_score:  0.9586092388437082
# [[15934  1436]
#  [   64 54538]]
# F1 score:  0.9864346693676747
# precision_score:  0.9743452317147246
# average_precision_score:  0.972052556315359
# recall_score:  0.9988278817625728
# roc:  0.995882030044513
# roc_weighted:  0.995999881863035
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7586561440560218
# Balanced loan passing rate: 0.7413021730605859
#
#
# score:  0.9292363696993275
# balanced_accuracy_score:  0.8619998767558503
# [[12563  4807]
#  [  286 54316]]
# F1 score:  0.9552165311057375
# precision_score:  0.9186949241411971
# average_precision_score:  0.9124505682297281
# recall_score:  0.9947620966264972
# roc:  0.9641354614752693
# roc_weighted:  0.9647840795566627
#
#
# 10 20
# MAIN CLASSIFER
# Loan passing rate: 0.7724567494238119
# Balanced loan passing rate: 0.7475995478751546
#
#
# score:  0.98141610992794
# balanced_accuracy_score:  0.9622548817602985
# [[14399  1200]
#  [   74 52881]]
# F1 score:  0.9880974625359692
# precision_score:  0.9778110611859988
# average_precision_score:  0.97529897511605
# recall_score:  0.9986025871022566
# roc:  0.995805189413127
# roc_weighted:  0.99593204096174
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7724567494238119
# Balanced loan passing rate: 0.7475995478751546
#
#
# score:  0.933001721270823
# balanced_accuracy_score:  0.8612643431583813
# [[11334  4265]
#  [  328 52627]]
# F1 score:  0.9581872968765646
# precision_score:  0.9250333966111228
# average_precision_score:  0.914697541115822
# recall_score:  0.9938060617505429
# roc:  0.9642128208637823
# roc_weighted:  0.9647247994885859
#
#
# 20 30
# MAIN CLASSIFER
# Loan passing rate: 0.7794971907437387
# Balanced loan passing rate: 0.7529445475413961
#
#
# score:  0.9799225470590103
# balanced_accuracy_score:  0.9576836959417205
# [[12713  1180]
#  [   85 49028]]
# F1 score:  0.98726351929602
# precision_score:  0.976497769279796
# average_precision_score:  0.9731373689711342
# recall_score:  0.9982692973347179
# roc:  0.9953261216025118
# roc_weighted:  0.9953688974011967
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7794971907437387
# Balanced loan passing rate: 0.7529445475413961
#
#
# score:  0.935149033425388
# balanced_accuracy_score:  0.8634661888778088
# [[10089  3804]
#  [  282 48831]]
# F1 score:  0.9598419624955774
# precision_score:  0.9277286976346537
# average_precision_score:  0.9180887450608967
# recall_score:  0.9942581393928288
# roc:  0.9652129577671398
# roc_weighted:  0.9657718201651121
#
#
# 30 40
# MAIN CLASSIFER
# Loan passing rate: 0.7870192307692307
# Balanced loan passing rate: 0.7608144134839486
#
#
# score:  0.9814903846153846
# balanced_accuracy_score:  0.9596931569493581
# [[11401  1003]
#  [   75 45761]]
# F1 score:  0.9883585313174945
# precision_score:  0.9785518775126165
# average_precision_score:  0.9754383093181008
# recall_score:  0.9983637315647089
# roc:  0.9957233539797355
# roc_weighted:  0.9958096801439397
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7870192307692307
# Balanced loan passing rate: 0.7608144134839486
#
#
# score:  0.9372767857142857
# balanced_accuracy_score:  0.8640745913770147
# [[ 8985  3419]
#  [  234 45602]]
# F1 score:  0.9614893998334335
# precision_score:  0.930254380775586
# average_precision_score:  0.9215196634096315
# recall_score:  0.994894842481892
# roc:  0.9631200308833487
# roc_weighted:  0.9651853937662396
#
#
# 40 50
# MAIN CLASSIFER
# Loan passing rate: 0.7948102021144754
# Balanced loan passing rate: 0.7663497548369754
#
#
# score:  0.9815480653008767
# balanced_accuracy_score:  0.9570179852054486
# [[12266  1145]
#  [   61 51887]]
# F1 score:  0.9885120975423891
# precision_score:  0.9784092623321768
# average_precision_score:  0.9745605867385485
# recall_score:  0.9988257488257488
# roc:  0.9952776003778911
# roc_weighted:  0.9954107507674262
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7948102021144754
# Balanced loan passing rate: 0.7663497548369754
#
#
# score:  0.9394115577043712
# balanced_accuracy_score:  0.8601002522894878
# [[ 9641  3770]
#  [  190 51758]]
# F1 score:  0.9631545647400349
# precision_score:  0.9321063247370696
# average_precision_score:  0.9215754009157919
# recall_score:  0.9963424963424964
# roc:  0.9644800700277548
# roc_weighted:  0.9655714470864791
#
#
# 50 60
# MAIN CLASSIFER
# Loan passing rate: 0.8040294590705155
# Balanced loan passing rate: 0.7763055367479574
#
#
# score:  0.9834250402099382
# balanced_accuracy_score:  0.9600849633385632
# [[10656   919]
#  [   60 47430]]
# F1 score:  0.9897849518463255
# precision_score:  0.9809923679910649
# average_precision_score:  0.9776046878681103
# recall_score:  0.9987365761212887
# roc:  0.99580209542807
# roc_weighted:  0.9957562929564836
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8040294590705155
# Balanced loan passing rate: 0.7763055367479574
#
#
# score:  0.941826800981969
# balanced_accuracy_score:  0.8583041678744388
# [[ 8255  3320]
#  [  116 47374]]
# F1 score:  0.9650044813818953
# precision_score:  0.9345090148735551
# average_precision_score:  0.9246176794636914
# recall_score:  0.9975573805011582
# roc:  0.9647813944688594
# roc_weighted:  0.9648829220439119
#
#
# 60 70
# MAIN CLASSIFER
# Loan passing rate: 0.8117283090387134
# Balanced loan passing rate: 0.7845664394150497
#
#
# score:  0.9829705398701191
# balanced_accuracy_score:  0.9572007641590337
# [[12359  1151]
#  [   71 58177]]
# F1 score:  0.9896067224603661
# precision_score:  0.9805993797195254
# average_precision_score:  0.9771188016592328
# recall_score:  0.9987810740282929
# roc:  0.9952763114474865
# roc_weighted:  0.9957010646628415
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8117283090387134
# Balanced loan passing rate: 0.7845664394150497
#
#
# score:  0.9444939937010508
# balanced_accuracy_score:  0.8597071979609907
# [[ 9699  3811]
#  [  172 58076]]
# F1 score:  0.9668456319973364
# precision_score:  0.9384200235913843
# average_precision_score:  0.928590729436575
# recall_score:  0.9970471089136108
# roc:  0.9624811597080343
# roc_weighted:  0.9638168367103053
#
#
# 70 80
# MAIN CLASSIFER
# Loan passing rate: 0.8231832011571649
# Balanced loan passing rate: 0.7990365384577551
#
#
# score:  0.9838229670640265
# balanced_accuracy_score:  0.9562216949858622
# [[ 9698   937]
#  [   36 49476]]
# F1 score:  0.990262697022767
# precision_score:  0.9814135242893698
# average_precision_score:  0.9784954015260716
# recall_score:  0.9992729035385362
# roc:  0.9948054241175727
# roc_weighted:  0.9952369948110966
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8231832011571649
# Balanced loan passing rate: 0.7990365384577551
#
#
# score:  0.9468967695811927
# balanced_accuracy_score:  0.8511450998501209
# [[ 7515  3120]
#  [   74 49438]]
# F1 score:  0.968707749583619
# precision_score:  0.9406370105407359
# average_precision_score:  0.9303860988216192
# recall_score:  0.9985054128292131
# roc:  0.9626655148133892
# roc_weighted:  0.9634560783495618
#
#
# 80 90
# MAIN CLASSIFER
# Loan passing rate: 0.8357135706897127
# Balanced loan passing rate: 0.8145621343890154
#
#
# score:  0.9851012713136909
# balanced_accuracy_score:  0.9559886392779442
# [[ 8983   864]
#  [   29 50062]]
# F1 score:  0.9911599037785719
# precision_score:  0.9830342064956996
# average_precision_score:  0.9803796245453186
# recall_score:  0.9994210536822982
# roc:  0.995466196074784
# roc_weighted:  0.9956228023909249
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8357135706897127
# Balanced loan passing rate: 0.8145621343890154
#
#
# score:  0.9499983316093297
# balanced_accuracy_score:  0.8495877739466566
# [[ 6884  2963]
#  [   34 50057]]
# F1 score:  0.9709342359205129
# precision_score:  0.9441154281403245
# average_precision_score:  0.9359266001059503
# recall_score:  0.99932123535166
# roc:  0.962721207816114
# roc_weighted:  0.9632761335394926
#
#
# 90 100
# MAIN CLASSIFER
# Loan passing rate: 0.8501862911621281
# Balanced loan passing rate: 0.8368548543149998
#
#
# score:  0.9868500356144869
# balanced_accuracy_score:  0.957028986121744
# [[ 9989   948]
#  [   12 62055]]
# F1 score:  0.9923242983929
# precision_score:  0.984953097471549
# average_precision_score:  0.9835277897560459
# recall_score:  0.9998066605442506
# roc:  0.9953400173684073
# roc_weighted:  0.9954241931844202
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8501862911621281
# Balanced loan passing rate: 0.8368548543149998
#
#
# score:  0.9555914744397567
# balanced_accuracy_score:  0.8539293701830009
# [[ 7737  3200]
#  [   42 62025]]
# F1 score:  0.9745309995914905
# precision_score:  0.9509390571100038
# average_precision_score:  0.9461282585161792
# recall_score:  0.999323311904877
# roc:  0.9628698487158532
# roc_weighted:  0.9626602186058735

# %% [markdown]
# The Global classifier has outperformed the locally trained version.

# %% [markdown]
# FICO test

# %%
for decile in [1,5,7,8,9,10]:
    print((decile-1)*10,decile*10)
    
    ml_test(df.loc[(df.fico_range_high > np.percentile(df.fico_range_high,(decile-1)*10)) & 
                   (df.fico_range_high<np.percentile(df.fico_range_high,decile*10))])
    print('\n')
# Out:
# 0 10
# MAIN CLASSIFER
# Loan passing rate: 0.7313474510264963
# Balanced loan passing rate: 0.6995969401756819
#
#
# score:  0.9769424074536718
# balanced_accuracy_score:  0.9605399706904182
# [[16862  1419]
#  [  150 49616]]
# F1 score:  0.9844346782273985
# precision_score:  0.9721955520721074
# average_precision_score:  0.9676961055272003
# recall_score:  0.9969858939838444
# roc:  0.9959202756334687
# roc_weighted:  0.9960333917814489
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7313474510264963
# Balanced loan passing rate: 0.6995969401756819
#
#
# score:  0.9214513498023424
# balanced_accuracy_score:  0.8637880408357643
# [[13464  4817]
#  [  528 49238]]
# F1 score:  0.9485171593415591
# precision_score:  0.9108870594764592
# average_precision_score:  0.8961129308188192
# recall_score:  0.9893903468231322
# roc:  0.964433758952018
# roc_weighted:  0.9650956658475641
#
#
# 40 50
# MAIN CLASSIFER
# Loan passing rate: 0.7851703564138798
# Balanced loan passing rate: 0.7650369482232141
#
#
# score:  0.9796867640131889
# balanced_accuracy_score:  0.954532527264393
# [[ 9956   990]
#  [   45 39961]]
# F1 score:  0.987215435354571
# precision_score:  0.975824766183976
# average_precision_score:  0.9729157154941313
# recall_score:  0.9988751687246913
# roc:  0.9958090735046786
# roc_weighted:  0.995669279260318
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7851703564138798
# Balanced loan passing rate: 0.7650369482232141
#
#
# score:  0.934899513267389
# balanced_accuracy_score:  0.8546889245770888
# [[ 7729  3217]
#  [  100 39906]]
# F1 score:  0.9600981606900119
# precision_score:  0.9253994388145537
# average_precision_score:  0.9181752327639392
# recall_score:  0.9975003749437584
# roc:  0.9632441005400442
# roc_weighted:  0.9648756057994385
#
#
# 60 70
# MAIN CLASSIFER
# Loan passing rate: 0.8146754237079674
# Balanced loan passing rate: 0.8011586105286239
#
#
# score:  0.9831746734558335
# balanced_accuracy_score:  0.9566448748712848
# [[ 6869   665]
#  [   19 33100]]
# F1 score:  0.9897733389151367
# precision_score:  0.9803050496075818
# average_precision_score:  0.978960385662316
# recall_score:  0.9994263111808931
# roc:  0.9950613550785921
# roc_weighted:  0.9951674121540666
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8146754237079674
# Balanced loan passing rate: 0.8011586105286239
#
#
# score:  0.9457112636213809
# balanced_accuracy_score:  0.8574584183835622
# [[ 5367  2167]
#  [   40 33079]]
# F1 score:  0.9677173992540041
# precision_score:  0.9385178459967088
# average_precision_score:  0.93395196051833
# recall_score:  0.9987922340650381
# roc:  0.9603962304268958
# roc_weighted:  0.9617220558523167
#
#
# 70 80
# MAIN CLASSIFER
# Loan passing rate: 0.8416479400749064
# Balanced loan passing rate: 0.8284318554066319
#
#
# score:  0.9854681647940075
# balanced_accuracy_score:  0.955470384487197
# [[ 8654   859]
#  [   14 50548]]
# F1 score:  0.9914385744687111
# precision_score:  0.983290213395063
# average_precision_score:  0.9818990327015957
# recall_score:  0.9997231122186623
# roc:  0.9950126602427587
# roc_weighted:  0.9952827026954978
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8416479400749064
# Balanced loan passing rate: 0.8284318554066319
#
#
# score:  0.9525593008739076
# balanced_accuracy_score:  0.8512811133184617
# [[ 6689  2824]
#  [   26 50536]]
# F1 score:  0.9725755855353052
# precision_score:  0.9470764617691154
# average_precision_score:  0.9419842694381816
# recall_score:  0.9994857798346585
# roc:  0.9605729861883805
# roc_weighted:  0.9617537681739687
#
#
# 80 90
# MAIN CLASSIFER
# Loan passing rate: 0.8697131745260087
# Balanced loan passing rate: 0.8589622865408598
#
#
# score:  0.9883325230918814
# balanced_accuracy_score:  0.9539742952695704
# [[ 5859   573]
#  [    3 42933]]
# F1 score:  0.9933365724994794
# precision_score:  0.9868294028409874
# average_precision_score:  0.9851121165314183
# recall_score:  0.9999301285634432
# roc:  0.9955363228777623
# roc_weighted:  0.9954595920154254
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8697131745260087
# Balanced loan passing rate: 0.8589622865408598
#
#
# score:  0.9614122508507535
# balanced_accuracy_score:  0.8504245220618233
# [[ 4535  1897]
#  [    8 42928]]
# F1 score:  0.9782933193559781
# precision_score:  0.9576798661461238
# average_precision_score:  0.9531819659330657
# recall_score:  0.999813676169182
# roc:  0.9628950155014939
# roc_weighted:  0.964494380520711
#
#
# 90 100
# MAIN CLASSIFER
# Loan passing rate: 0.9106408867652951
# Balanced loan passing rate: 0.897879558663348
#
#
# score:  0.991556736062679
# balanced_accuracy_score:  0.9549612766475164
# [[ 5458   564]
#  [    5 61364]]
# F1 score:  0.9953851269698369
# precision_score:  0.9908926495284847
# average_precision_score:  0.9898600598996146
# recall_score:  0.9999185256399811
# roc:  0.9941120514843923
# roc_weighted:  0.9941854835922218
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.9106408867652951
# Balanced loan passing rate: 0.897879558663348
#
#
# score:  0.972652134558027
# balanced_accuracy_score:  0.849313703738621
# [[ 4187  1835]
#  [    8 61361]]
# F1 score:  0.9852045117007185
# precision_score:  0.9709633521108931
# average_precision_score:  0.9668603032037602
# recall_score:  0.9998696410239698
# roc:  0.962335561484354
# roc_weighted:  0.9637339925791302

# %%
feature_importance = pd.DataFrame(data = rf_best.feature_importances_,index=X.columns,columns=['feature_importance'])
feature_importance.sort_values(by='feature_importance',ascending =False)
# Out:
#                                            feature_importance
# int_rate                                             0.047555
# dti                                                  0.030253
# installment                                          0.026801
# annual_inc                                           0.024744
# length_of_cr                                         0.024518
# revol_util                                           0.024386
# revol_bal                                            0.023915
# bc_open_to_buy                                       0.023277
# tot_hi_cred_lim                                      0.023141
# avg_cur_bal                                          0.022902
# bc_util                                              0.022183
# mo_sin_old_rev_tl_op                                 0.022051
# loan_amnt                                            0.022044
# total_bc_limit                                       0.021938
# tot_cur_bal                                          0.021895
# total_bal_ex_mort                                    0.021523
# total_rev_hi_lim                                     0.021410
# mo_sin_old_il_acct                                   0.021233
# total_acc                                            0.019392
# total_il_high_credit_limit                           0.019182
# mths_since_recent_bc                                 0.018912
# fico_range_low                                       0.016912
# fico_range_high                                      0.016543
# term                                                 0.016323
# mo_sin_rcnt_rev_tl_op                                0.015812
# num_rev_accts                                        0.015666
# num_il_tl                                            0.015249
# mths_since_recent_inq                                0.015160
# mo_sin_rcnt_tl                                       0.014436
# open_acc                                             0.014245
# ...                                                       ...
# delinq_amnt                                          0.000271
# revol_bal_joint                                      0.000267
# sub_grade_F4                                         0.000263
# sec_length_of_cr                                     0.000260
# sec_app_fico_range_low                               0.000249
# sec_app_fico_range_high                              0.000240
# sec_app_num_rev_accts                                0.000239
# sec_app_open_acc                                     0.000235
# sub_grade_F5                                         0.000231
# application_type                                     0.000228
# acc_now_delinq                                       0.000215
# sec_app_open_act_il                                  0.000196
# num_tl_30dpd                                         0.000155
# sub_grade_G1                                         0.000153
# sec_app_inq_last_6mths                               0.000151
# sec_app_mths_since_last_major_derog                  0.000135
# purpose_wedding                                      0.000135
# disbursement_method                                  0.000122
# sub_grade_G2                                         0.000116
# sec_app_mort_acc                                     0.000115
# sub_grade_G3                                         0.000086
# purpose_renewable_energy                             0.000078
# sub_grade_G4                                         0.000067
# verification_status_joint_Source Verified            0.000066
# sub_grade_G5                                         0.000058
# verification_status_joint_Verified                   0.000050
# sec_app_collections_12_mths_ex_med                   0.000043
# purpose_educational                                  0.000040
# num_tl_120dpd_2m                                     0.000035
# sec_app_chargeoff_within_12_mths                     0.000018
#
# [146 rows x 1 columns]
