# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('lending_club_ml.csv')
df.drop(['id'], inplace=True, axis=1)

# %%
# creating columns for features that had more than 2 outcomes
# I have decided to use subgrade and not grade as these are suppose to be similar features but, subgrade is more granular

df = pd.concat([df, pd.get_dummies(
    df.sub_grade, prefix='sub_grade', drop_first=True)], axis=1)
df = pd.concat([df, pd.get_dummies(df.home_ownership,
                                   prefix='home_ownership', drop_first=True)], axis=1)
df = pd.concat([df, pd.get_dummies(df.verification_status,
                                   prefix='verification_status', drop_first=True)], axis=1)
df = pd.concat(
    [df, pd.get_dummies(df.purpose, prefix='purpose', drop_first=True)], axis=1)
df = pd.concat([df, pd.get_dummies(df.verification_status_joint,
                                   prefix='verification_status_joint', drop_first=True)], axis=1)

df.drop(columns=['sub_grade', 'home_ownership', 'verification_status',
                 'purpose', 'verification_status_joint'], inplace=True)


# conversions for features that only had 2 outcomes

df.disbursement_method = df.disbursement_method.apply(
    lambda disburstment: 1 if disburstment == 'Cash' else 0)

df.application_type = df.application_type.apply(
    lambda app_type: 1 if app_type == 'Individual' else 0)

# %%
"""# if borrower is an indivudal then their secondary features are filled with their single counterpart

sec_list = ['sec_app_fico_range_low', 'sec_app_fico_range_high', 'sec_app_inq_last_6mths', 'sec_app_mort_acc',
            'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il','sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths',
            'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog']
joint_list = ['dti_joint', 'revol_bal_joint', 'annual_inc_joint']

for secondary in sec_list:
    df.loc[df.application_type == 1,secondary] = df.loc[df.application_type == 1][secondary[8:]]


for joint in joint_list:
    df.loc[df.application_type == 1,joint] = df.loc[df.application_type == 1][joint[:len(joint)-6]]

df.info()"""
# Out:
# "# if borrower is an indivudal then their secondary features are filled with their single counterpart\n\nsec_list = ['sec_app_fico_range_low', 'sec_app_fico_range_high', 'sec_app_inq_last_6mths', 'sec_app_mort_acc',\n            'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il','sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths',\n            'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog']\njoint_list = ['dti_joint', 'revol_bal_joint', 'annual_inc_joint']\n\nfor secondary in sec_list:\n    df.loc[df.application_type == 1,secondary] = df.loc[df.application_type == 1][secondary[8:]]\n\n\nfor joint in joint_list:\n    df.loc[df.application_type == 1,joint] = df.loc[df.application_type == 1][joint[:len(joint)-6]]\n\ndf.info()"

# %%
#fill all nans with 0
df.fillna(0, inplace=True)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score


def scoring(clf, x, y):
    
    #Baseline
    print('Loan passing rate:', np.mean(y))
    print('Balanced loan passing rate:', np.average(y, weights=x['loan_amnt']))
    print('\n')
    
    
    print('score: ', clf.score(x, y))
    # score adjusted for loan amount
    print('balanced_accuracy_score: ', balanced_accuracy_score(
        y, clf.predict(x), sample_weight=x['loan_amnt']))

    print(confusion_matrix(y, clf.predict(x)))
    
    print('F1 score: ', f1_score(y, clf.predict(x)))
    
    print('precision_score: ', precision_score(y, clf.predict(x)))

    # score adjusted for loan amount
    print('average_precision_score: ', average_precision_score(
        y, clf.predict(x), average='weighted', sample_weight=x['loan_amnt']))
    
    print('recall_score: ', recall_score(y, clf.predict(x)))

    print('roc: ', roc_auc_score(y, clf.predict_proba(x)[:, 1]))

    # score adjusted for loan amount
    print('roc_weighted: ', roc_auc_score(y, clf.predict_proba(x)[
          :, 1], average='weighted', sample_weight=x['loan_amnt']))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X = df.drop(['grade','loan_status'], axis=1)
y = df.loan_status

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)



rf_best = RandomForestClassifier(criterion= 'entropy', n_estimators= 101)
rf_best.fit(X_train, y_train)
    
print('RANDOM FOREST')
scoring(rf_best, X_test, y_test)
# Out:
# RANDOM FOREST
# Loan passing rate: 0.8009672589365736
# Balanced loan passing rate: 0.7855872316459166
#
#
# score:  0.9414338942211797
# balanced_accuracy_score:  0.8602320692946972
# [[108066  41611]
#  [  2432 599913]]
# F1 score:  0.96459193050072
# precision_score:  0.9351372668832343
# average_precision_score:  0.9292499991517935
# recall_score:  0.9959624467705385
# roc:  0.9647261565103948
# roc_weighted:  0.9655150527937684

# %% [markdown]
# # Testing based off of certain features
# Here will be testing our classifier, that was trained and test on the general populatyion with global averages to fill the nans, on certain sub-groups of the population and to see if we need to fill nans with local averages.

# %%
def ml_test(dataframe):
    dataframe.fillna(0,inplace=True)
    
    X = dataframe.drop(['grade','loan_status'], axis=1)
    y = dataframe.loan_status

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
    print('MAIN CLASSIFER')
    scoring(rf_best, X_test, y_test)
    
    print('\n')
    print('RETRAINED CLASSIFER')
    rf = RandomForestClassifier(criterion= 'entropy', n_estimators= 101)
    rf.fit(X_train, y_train)
    scoring(rf, X_test, y_test)

# %% [markdown]
# Individual verse joint: in our EDA joint borrowers failed in higher rates and had wide differences between their single and joint/secondary features.

# %%
ml_test(df.loc[df.application_type == 1])
# Out:
# MAIN CLASSIFER
# Loan passing rate: 0.8018762389397847
# Balanced loan passing rate: 0.7866714294905874
#
#
# score:  0.9763675398788487
# balanced_accuracy_score:  0.9433116183374979
# [[130230  16591]
#  [   922 593314]]
# F1 score:  0.985456022176805
# precision_score:  0.9727974028742181
# average_precision_score:  0.970257096591743
# recall_score:  0.9984484278973337
# roc:  0.9923590577367548
# roc_weighted:  0.9925843852868556
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8018762389397847
# Balanced loan passing rate: 0.7866714294905874
#
#
# score:  0.9412244942022003
# balanced_accuracy_score:  0.8590018069866086
# [[105551  41270]
#  [  2286 591950]]
# F1 score:  0.9645152249856614
# precision_score:  0.9348251792426013
# average_precision_score:  0.9290911291607827
# recall_score:  0.9961530435719141
# roc:  0.964107709067975
# roc_weighted:  0.9649290820221007

# %%
ml_test(df.loc[df.application_type == 0])
# Out:
# MAIN CLASSIFER
# Loan passing rate: 0.7680802553579571
# Balanced loan passing rate: 0.7633904760778214
#
#
# score:  0.9803921568627451
# balanced_accuracy_score:  0.9620772593993847
# [[2349  194]
#  [  21 8401]]
# F1 score:  0.9873655756008697
# precision_score:  0.9774287376381617
# average_precision_score:  0.9771611732540505
# recall_score:  0.997506530515317
# roc:  0.9969369634964435
# roc_weighted:  0.9972945724052852
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7680802553579571
# Balanced loan passing rate: 0.7633904760778214
#
#
# score:  0.9246694026447788
# balanced_accuracy_score:  0.8421763473166493
# [[1759  784]
#  [  42 8380]]
# F1 score:  0.953030819970431
# precision_score:  0.9144478393714535
# average_precision_score:  0.9109824214358477
# recall_score:  0.995013061030634
# roc:  0.9617813690022005
# roc_weighted:  0.9609105541013541

# %% [markdown]
# The Global classifier has outperformed the locally trained version.

# %% [markdown]
# ML for different grades

# %%
grades = set(df.grade)

for loan_grade in sorted(grades):
    print(loan_grade)
    ml_test(df.loc[df.grade==loan_grade])
    print('\n')
# Out:
# A
# MAIN CLASSIFER
# Loan passing rate: 0.9405104807551982
# Balanced loan passing rate: 0.9413940416432522
#
#
# score:  0.9946156032291018
# balanced_accuracy_score:  0.9569929927858436
# [[  7044    701]
#  [     0 122446]]
# F1 score:  0.9971456841196614
# precision_score:  0.9943076161010824
# average_precision_score:  0.9946737664195048
# recall_score:  1.0
# roc:  0.9919760937660329
# roc_weighted:  0.9917791211787231
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.9405104807551982
# Balanced loan passing rate: 0.9413940416432522
#
#
# score:  0.9826792942676529
# balanced_accuracy_score:  0.8521310558351796
# [[  5490   2255]
#  [     0 122446]]
# F1 score:  0.9908758754911045
# precision_score:  0.9819167448536901
# average_precision_score:  0.9819218404712945
# recall_score:  1.0
# roc:  0.9482498038396964
# roc_weighted:  0.9467508719636832
#
#
# B
# MAIN CLASSIFER
# Loan passing rate: 0.8673473571985074
# Balanced loan passing rate: 0.8650654540003315
#
#
# score:  0.9879626212508485
# balanced_accuracy_score:  0.9544207973578072
# [[ 26473   2642]
#  [     0 190368]]
# F1 score:  0.993108629081481
# precision_score:  0.9863115900730532
# average_precision_score:  0.9859802866475508
# recall_score:  1.0
# roc:  0.9950569168135518
# roc_weighted:  0.9950161081872753
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8673473571985074
# Balanced loan passing rate: 0.8650654540003315
#
#
# score:  0.9598921100950871
# balanced_accuracy_score:  0.8500200626337842
# [[ 20312   8803]
#  [     0 190368]]
# F1 score:  0.977401492533482
# precision_score:  0.9558017984545943
# average_precision_score:  0.9553029888473147
# recall_score:  1.0
# roc:  0.9552890702403252
# roc_weighted:  0.9558167611940289
#
#
# C
# MAIN CLASSIFER
# Loan passing rate: 0.7772935382135309
# Balanced loan passing rate: 0.7696991390065671
#
#
# score:  0.980004030122825
# balanced_accuracy_score:  0.9553395609172127
# [[ 43301   4223]
#  [    44 165825]]
# F1 score:  0.9872974574076334
# precision_score:  0.9751658355287919
# average_precision_score:  0.9739850398182796
# recall_score:  0.9997347304197891
# roc:  0.9958916262509367
# roc_weighted:  0.9958927777840201
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7772935382135309
# Balanced loan passing rate: 0.7696991390065671
#
#
# score:  0.9336154419310849
# balanced_accuracy_score:  0.8522377822253469
# [[ 33408  14116]
#  [    50 165819]]
# F1 score:  0.9590345976333415
# precision_score:  0.9215494484119265
# average_precision_score:  0.9187697680202729
# recall_score:  0.999698557295215
# roc:  0.9607661096493467
# roc_weighted:  0.961015805121769
#
#
# D
# MAIN CLASSIFER
# Loan passing rate: 0.6985549107182656
# Balanced loan passing rate: 0.684318232759796
#
#
# score:  0.9729970670303906
# balanced_accuracy_score:  0.9566884061765997
# [[31008  2806]
#  [  223 78136]]
# F1 score:  0.9809856811947194
# precision_score:  0.9653332015517284
# average_precision_score:  0.9619383105719322
# recall_score:  0.9971541239678914
# roc:  0.9965494460473271
# roc_weighted:  0.9965464061235267
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.6985549107182656
# Balanced loan passing rate: 0.684318232759796
#
#
# score:  0.9114760236420529
# balanced_accuracy_score:  0.8582704908831738
# [[24408  9406]
#  [  524 77835]]
# F1 score:  0.9400362318840579
# precision_score:  0.8921837209568896
# average_precision_score:  0.884787488581258
# recall_score:  0.9933128294133412
# roc:  0.9633574464826299
# roc_weighted:  0.963696113001329
#
#
# E
# MAIN CLASSIFER
# Loan passing rate: 0.6156433188035473
# Balanced loan passing rate: 0.6043316083087944
#
#
# score:  0.9666691718021945
# balanced_accuracy_score:  0.9577784157808362
# [[18932  1525]
#  [  249 32518]]
# F1 score:  0.9734470887591677
# precision_score:  0.9552037129512675
# average_precision_score:  0.9492032531220049
# recall_score:  0.9924008911404767
# roc:  0.9964776393273976
# roc_weighted:  0.996307501257959
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.6156433188035473
# Balanced loan passing rate: 0.6043316083087944
#
#
# score:  0.8879452878400721
# balanced_accuracy_score:  0.8609141553635313
# [[15573  4884]
#  [ 1080 31687]]
# F1 score:  0.9139865585970175
# precision_score:  0.8664515599792185
# average_precision_score:  0.8493327191507255
# recall_score:  0.9670400097659231
# roc:  0.9644044559327232
# roc_weighted:  0.9633118375063874
#
#
# F
# MAIN CLASSIFER
# Loan passing rate: 0.549331012727075
# Balanced loan passing rate: 0.5378723846276439
#
#
# score:  0.9630697269661699
# balanced_accuracy_score:  0.959961504902837
# [[7776  510]
#  [ 169 9931]]
# F1 score:  0.9669441604595688
# precision_score:  0.9511541040130256
# average_precision_score:  0.9407629745805924
# recall_score:  0.9832673267326733
# roc:  0.9968813494311053
# roc_weighted:  0.9967235110577081
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.549331012727075
# Balanced loan passing rate: 0.5378723846276439
#
#
# score:  0.8754487109757424
# balanced_accuracy_score:  0.8668747743030933
# [[6836 1450]
#  [ 840 9260]]
# F1 score:  0.8899567515617492
# precision_score:  0.8646125116713352
# average_precision_score:  0.8279093163966009
# recall_score:  0.9168316831683169
# roc:  0.9638173777551541
# roc_weighted:  0.9619364715510663
#
#
# G
# MAIN CLASSIFER
# Loan passing rate: 0.49284885968303055
# Balanced loan passing rate: 0.4956165657835817
#
#
# score:  0.964824120603015
# balanced_accuracy_score:  0.9671601830666039
# [[2499  125]
#  [  57 2493]]
# F1 score:  0.9647832817337462
# precision_score:  0.9522536287242169
# average_precision_score:  0.9457812609727961
# recall_score:  0.9776470588235294
# roc:  0.9971787571736012
# roc_weighted:  0.9974097495568521
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.49284885968303055
# Balanced loan passing rate: 0.4956165657835817
#
#
# score:  0.8790104367993815
# balanced_accuracy_score:  0.8765733071925308
# [[2302  322]
#  [ 304 2246]]
# F1 score:  0.87768659632669
# precision_score:  0.8746105919003115
# average_precision_score:  0.823802990052638
# recall_score:  0.8807843137254902
# roc:  0.9632493424198948
# roc_weighted:  0.9618229183047688

# %% [markdown]
# The Global classifier has outperformed the locally trained version.

# %% [markdown]
# ML for different loan sizes

# %%
for decile in np.arange(1,11):
    print((decile-1)*10,decile*10)
    
    ml_test(df.loc[(df.loan_amnt > np.percentile(df.loan_amnt,(decile-1)*10)) & 
                   (df.loan_amnt<np.percentile(df.loan_amnt,decile*10))])
    print('\n')
# Out:
# 0 10
# MAIN CLASSIFER
# Loan passing rate: 0.8456880009798451
# Balanced loan passing rate: 0.8423225500026952
#
#
# score:  0.9861052516977178
# balanced_accuracy_score:  0.9555562898555657
# [[10326  1013]
#  [    8 62134]]
# F1 score:  0.9918508408559411
# precision_score:  0.9839580660997356
# average_precision_score:  0.9836367758197843
# recall_score:  0.9998712625921277
# roc:  0.9952201028906399
# roc_weighted:  0.9951601291320926
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8456880009798451
# Balanced loan passing rate: 0.8423225500026952
#
#
# score:  0.9555803541051429
# balanced_accuracy_score:  0.8568450615562462
# [[ 8093  3246]
#  [   18 62124]]
# F1 score:  0.9744024091850179
# precision_score:  0.9503441945846719
# average_precision_score:  0.9491349835172084
# recall_score:  0.9997103408322874
# roc:  0.9628632145257872
# roc_weighted:  0.9623637362351344
#
#
# 10 20
# MAIN CLASSIFER
# Loan passing rate: 0.8402740327960533
# Balanced loan passing rate: 0.8404687232746312
#
#
# score:  0.9848003675075399
# balanced_accuracy_score:  0.9527464853872627
# [[ 7242   755]
#  [    6 42064]]
# F1 score:  0.9910353520479686
# precision_score:  0.9823676405334081
# average_precision_score:  0.9823811096702448
# recall_score:  0.9998573805562159
# roc:  0.9949682922752794
# roc_weighted:  0.9949881297374557
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8402740327960533
# Balanced loan passing rate: 0.8404687232746312
#
#
# score:  0.9508858130105659
# balanced_accuracy_score:  0.848252585126464
# [[ 5576  2421]
#  [   38 42032]]
# F1 score:  0.9715798111484808
# precision_score:  0.945537983938092
# average_precision_score:  0.9455426345709879
# recall_score:  0.9990967435227003
# roc:  0.9588704422347114
# roc_weighted:  0.9589137621383333
#
#
# 20 30
# MAIN CLASSIFER
# Loan passing rate: 0.8309950443577244
# Balanced loan passing rate: 0.8307076537011601
#
#
# score:  0.9847144766868763
# balanced_accuracy_score:  0.9551371281459057
# [[11397  1119]
#  [   13 61528]]
# F1 score:  0.9908847875801206
# precision_score:  0.9821380113971938
# average_precision_score:  0.9820486696389183
# recall_score:  0.9997887587137031
# roc:  0.9952646920256853
# roc_weighted:  0.9952465388820774
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8309950443577244
# Balanced loan passing rate: 0.8307076537011601
#
#
# score:  0.9492282971224867
# balanced_accuracy_score:  0.8509592293092862
# [[ 8792  3724]
#  [   36 61505]]
# F1 score:  0.970339985801057
# precision_score:  0.9429088288951233
# average_precision_score:  0.9427406925949188
# recall_score:  0.9994150241302546
# roc:  0.9593239601653265
# roc_weighted:  0.9593112889798581
#
#
# 30 40
# MAIN CLASSIFER
# Loan passing rate: 0.8246477617264134
# Balanced loan passing rate: 0.8243078159533855
#
#
# score:  0.9847333690030319
# balanced_accuracy_score:  0.9569744342797857
# [[ 4493   423]
#  [    5 23114]]
# F1 score:  0.990826474622771
# precision_score:  0.9820282958745804
# average_precision_score:  0.9819960138001224
# recall_score:  0.9997837276698819
# roc:  0.9959764239931572
# roc_weighted:  0.9959974134351874
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8246477617264134
# Balanced loan passing rate: 0.8243078159533855
#
#
# score:  0.945211342964152
# balanced_accuracy_score:  0.8465834095728372
# [[ 3414  1502]
#  [   34 23085]]
# F1 score:  0.9678027921016225
# precision_score:  0.9389108065237727
# average_precision_score:  0.9386399624886301
# recall_score:  0.998529348155197
# roc:  0.9574066339680736
# roc_weighted:  0.9574489122635327
#
#
# 40 50
# MAIN CLASSIFER
# Loan passing rate: 0.7700934579439253
# Balanced loan passing rate: 0.769898129472552
#
#
# score:  0.9807698400126723
# balanced_accuracy_score:  0.9604191882817434
# [[ 6696   561]
#  [   46 24262]]
# F1 score:  0.9876452748773688
# precision_score:  0.9773999919429561
# average_precision_score:  0.9769938808161971
# recall_score:  0.9981076188909002
# roc:  0.9958788010572781
# roc_weighted:  0.9958806828227176
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7700934579439253
# Balanced loan passing rate: 0.769898129472552
#
#
# score:  0.9319499445588468
# balanced_accuracy_score:  0.8611733920321717
# [[ 5303  1954]
#  [  194 24114]]
# F1 score:  0.9573606479275847
# precision_score:  0.9250421973300599
# average_precision_score:  0.9236233273773233
# recall_score:  0.9920190883659701
# roc:  0.9641367357395805
# roc_weighted:  0.9640743011437706
#
#
# 50 60
# MAIN CLASSIFER
# Loan passing rate: 0.7779965593715672
# Balanced loan passing rate: 0.7779150376575796
#
#
# score:  0.9797707629489917
# balanced_accuracy_score:  0.9573306633803065
# [[ 9821   890]
#  [   86 37450]]
# F1 score:  0.9871369075860614
# precision_score:  0.9767866458007303
# average_precision_score:  0.9763326111927703
# recall_score:  0.9977088661551577
# roc:  0.995804627563763
# roc_weighted:  0.9958134423312628
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7779965593715672
# Balanced loan passing rate: 0.7779150376575796
#
#
# score:  0.9378199680809169
# balanced_accuracy_score:  0.8691689672795881
# [[ 7979  2732]
#  [  268 37268]]
# F1 score:  0.9613082955014444
# precision_score:  0.9317
# average_precision_score:  0.9307073852350297
# recall_score:  0.9928601875532822
# roc:  0.9699143656683304
# roc_weighted:  0.9700337001836051
#
#
# 60 70
# MAIN CLASSIFER
# Loan passing rate: 0.7649989444796285
# Balanced loan passing rate: 0.7648301164890858
#
#
# score:  0.9799240025332489
# balanced_accuracy_score:  0.9603418547439626
# [[10280   852]
#  [   99 36139]]
# F1 score:  0.9870133417088859
# precision_score:  0.9769673704414588
# average_precision_score:  0.9763540749787065
# recall_score:  0.9972680611512776
# roc:  0.9964817277686502
# roc_weighted:  0.9964801339079128
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7649989444796285
# Balanced loan passing rate: 0.7648301164890858
#
#
# score:  0.9320878192949124
# balanced_accuracy_score:  0.8637479086670301
# [[ 8183  2949]
#  [  268 35970]]
# F1 score:  0.9571962691432601
# precision_score:  0.9242272411932475
# average_precision_score:  0.9229306012476812
# recall_score:  0.9926044483691153
# roc:  0.9674145541422691
# roc_weighted:  0.967420842612801
#
#
# 70 80
# MAIN CLASSIFER
# Loan passing rate: 0.7735375221587552
# Balanced loan passing rate: 0.7739097135273253
#
#
# score:  0.9798273258485982
# balanced_accuracy_score:  0.9581088383456562
# [[12674  1123]
#  [  106 47021]]
# F1 score:  0.9870999569648686
# precision_score:  0.9766741442339648
# average_precision_score:  0.976226988979888
# recall_score:  0.9977507585884949
# roc:  0.9957972180113982
# roc_weighted:  0.9957834012877106
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7735375221587552
# Balanced loan passing rate: 0.7739097135273253
#
#
# score:  0.9337535289869345
# balanced_accuracy_score:  0.8635636962939186
# [[10149  3648]
#  [  388 46739]]
# F1 score:  0.9586110712307977
# precision_score:  0.9276003731121123
# average_precision_score:  0.926415966169805
# recall_score:  0.9917669276635475
# roc:  0.9660326669940158
# roc_weighted:  0.9660254300641641
#
#
# 80 90
# MAIN CLASSIFER
# Loan passing rate: 0.7722949285584592
# Balanced loan passing rate: 0.7724105678601824
#
#
# score:  0.9793008086931017
# balanced_accuracy_score:  0.9572800515765414
# [[14940  1363]
#  [  119 55175]]
# F1 score:  0.9867479791115245
# precision_score:  0.9758923202094166
# average_precision_score:  0.975558489616846
# recall_score:  0.9978478677614208
# roc:  0.9957357640063844
# roc_weighted:  0.9957211503820667
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7722949285584592
# Balanced loan passing rate: 0.7724105678601824
#
#
# score:  0.9327904800480467
# balanced_accuracy_score:  0.8615175840827063
# [[11911  4392]
#  [  420 54874]]
# F1 score:  0.957995810055866
# precision_score:  0.9258934296223804
# average_precision_score:  0.9247777918519177
# recall_score:  0.9924042391579556
# roc:  0.9665471677472852
# roc_weighted:  0.9665199235455719
#
#
# 90 100
# MAIN CLASSIFER
# Loan passing rate: 0.7571632205262905
# Balanced loan passing rate: 0.7572959629998549
#
#
# score:  0.9788907218476224
# balanced_accuracy_score:  0.9579217307438969
# [[13903  1259]
#  [   59 47216]]
# F1 score:  0.9862349869451696
# precision_score:  0.9740278494069108
# average_precision_score:  0.9738146872239157
# recall_score:  0.9987519830777366
# roc:  0.9961599097802956
# roc_weighted:  0.996169936976421
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7571632205262905
# Balanced loan passing rate: 0.7572959629998549
#
#
# score:  0.9284718996748723
# balanced_accuracy_score:  0.8598433343677874
# [[11020  4142]
#  [  324 46951]]
# F1 score:  0.9545990566037736
# precision_score:  0.9189321433464467
# average_precision_score:  0.917803002473044
# recall_score:  0.9931464833421471
# roc:  0.9638948577991222
# roc_weighted:  0.9638576405467292

# %% [markdown]
# The Global classifier has outperformed the locally trained version.

# %% [markdown]
# Annual Income by decile

# %%
for decile in np.arange(1,11):
    print((decile-1)*10,decile*10)
    
    ml_test(df.loc[(df.annual_inc > np.percentile(df.annual_inc,(decile-1)*10)) & 
                   (df.annual_inc<np.percentile(df.annual_inc,decile*10))])
    print('\n')
# Out:
# 0 10
# MAIN CLASSIFER
# Loan passing rate: 0.7586561440560218
# Balanced loan passing rate: 0.7413021730605859
#
#
# score:  0.9791863502473184
# balanced_accuracy_score:  0.9589275077722865
# [[15939  1431]
#  [   67 54535]]
# F1 score:  0.9864517762824687
# precision_score:  0.9744309044777186
# average_precision_score:  0.972259252969048
# recall_score:  0.9987729387201933
# roc:  0.9958718448633695
# roc_weighted:  0.9959721504534519
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7586561440560218
# Balanced loan passing rate: 0.7413021730605859
#
#
# score:  0.9300700272328127
# balanced_accuracy_score:  0.8644998304067847
# [[12631  4739]
#  [  294 54308]]
# F1 score:  0.9557145245448706
# precision_score:  0.9197419005199248
# average_precision_score:  0.9139124711659499
# recall_score:  0.9946155818468188
# roc:  0.963115460921516
# roc_weighted:  0.9638310292572698
#
#
# 10 20
# MAIN CLASSIFER
# Loan passing rate: 0.7724567494238119
# Balanced loan passing rate: 0.7475995478751546
#
#
# score:  0.9814890451323045
# balanced_accuracy_score:  0.9625079391509135
# [[14404  1195]
#  [   74 52881]]
# F1 score:  0.9881436219413066
# precision_score:  0.977901472002367
# average_precision_score:  0.9754496484690002
# recall_score:  0.9986025871022566
# roc:  0.9958500592422294
# roc_weighted:  0.9959347493893064
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7724567494238119
# Balanced loan passing rate: 0.7475995478751546
#
#
# score:  0.9325495230037635
# balanced_accuracy_score:  0.8613547781941135
# [[11349  4250]
#  [  374 52581]]
# F1 score:  0.9578816971198514
# precision_score:  0.9252168710738857
# average_precision_score:  0.9147956505071287
# recall_score:  0.9929373996789728
# roc:  0.9639531873228535
# roc_weighted:  0.9645181334586809
#
#
# 20 30
# MAIN CLASSIFER
# Loan passing rate: 0.7794971907437387
# Balanced loan passing rate: 0.7529445475413961
#
#
# score:  0.9794781449385773
# balanced_accuracy_score:  0.9576937099593179
# [[12721  1172]
#  [  121 48992]]
# F1 score:  0.9869758352891405
# precision_score:  0.97663663184754
# average_precision_score:  0.973212129736527
# recall_score:  0.9975362938529514
# roc:  0.9954611800309345
# roc_weighted:  0.9955546946332533
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7794971907437387
# Balanced loan passing rate: 0.7529445475413961
#
#
# score:  0.9350220613909787
# balanced_accuracy_score:  0.8637427766592323
# [[10099  3794]
#  [  300 48813]]
# F1 score:  0.9597522611089265
# precision_score:  0.9278803201094912
# average_precision_score:  0.9182612559246616
# recall_score:  0.9938916376519455
# roc:  0.9650639719970358
# roc_weighted:  0.9655516468911439
#
#
# 30 40
# MAIN CLASSIFER
# Loan passing rate: 0.7870192307692307
# Balanced loan passing rate: 0.7608144134839486
#
#
# score:  0.9819196428571428
# balanced_accuracy_score:  0.9603534821031343
# [[11419   985]
#  [   68 45768]]
# F1 score:  0.9886271587337588
# precision_score:  0.9789318332513421
# average_precision_score:  0.9758164898639692
# recall_score:  0.9985164499520028
# roc:  0.9956361654786005
# roc_weighted:  0.995762420816082
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7870192307692307
# Balanced loan passing rate: 0.7608144134839486
#
#
# score:  0.937396978021978
# balanced_accuracy_score:  0.8636899619899683
# [[ 8988  3416]
#  [  230 45606]]
# F1 score:  0.9615636003289127
# precision_score:  0.9303170005303741
# average_precision_score:  0.9213193030988684
# recall_score:  0.9949821101317742
# roc:  0.9634374296719409
# roc_weighted:  0.964992867847617
#
#
# 40 50
# MAIN CLASSIFER
# Loan passing rate: 0.7948102021144754
# Balanced loan passing rate: 0.7663497548369754
#
#
# score:  0.9817622668645481
# balanced_accuracy_score:  0.9581191777351628
# [[12290  1121]
#  [   71 51877]]
# F1 score:  0.9886417776761383
# precision_score:  0.9788482584248462
# average_precision_score:  0.9752170457144533
# recall_score:  0.9986332486332486
# roc:  0.9952746298376751
# roc_weighted:  0.9953966739778755
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7948102021144754
# Balanced loan passing rate: 0.7663497548369754
#
#
# score:  0.9403295644058202
# balanced_accuracy_score:  0.8623435161909836
# [[ 9683  3728]
#  [  172 51776]]
# F1 score:  0.9637047239697725
# precision_score:  0.9328336696454309
# average_precision_score:  0.9227200170921136
# recall_score:  0.9966889966889967
# roc:  0.9651672329884246
# roc_weighted:  0.9663693591344557
#
#
# 50 60
# MAIN CLASSIFER
# Loan passing rate: 0.8040294590705155
# Balanced loan passing rate: 0.7763055367479574
#
#
# score:  0.9832049437060865
# balanced_accuracy_score:  0.9591894273167865
# [[10637   938]
#  [   54 47436]]
# F1 score:  0.9896520070099307
# precision_score:  0.9806094182825484
# average_precision_score:  0.9771048725393328
# recall_score:  0.9988629185091599
# roc:  0.9960913239890904
# roc_weighted:  0.9960014957277057
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8040294590705155
# Balanced loan passing rate: 0.7763055367479574
#
#
# score:  0.9410479979683399
# balanced_accuracy_score:  0.8572192490367585
# [[ 8243  3332]
#  [  150 47340]]
# F1 score:  0.9645280251013632
# precision_score:  0.9342437638143354
# average_precision_score:  0.9241077243989819
# recall_score:  0.9968414403032217
# roc:  0.9643385302896552
# roc_weighted:  0.964887566921756
#
#
# 60 70
# MAIN CLASSIFER
# Loan passing rate: 0.8117283090387134
# Balanced loan passing rate: 0.7845664394150497
#
#
# score:  0.9829705398701191
# balanced_accuracy_score:  0.9576936437465398
# [[12369  1141]
#  [   81 58167]]
# F1 score:  0.9896049542345776
# precision_score:  0.9807614487084373
# average_precision_score:  0.977388139530056
# recall_score:  0.9986093943139679
# roc:  0.9952578339575816
# roc_weighted:  0.9956049466563724
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8117283090387134
# Balanced loan passing rate: 0.7845664394150497
#
#
# score:  0.9444103793305276
# balanced_accuracy_score:  0.8591362905068496
# [[ 9689  3821]
#  [  168 58080]]
# F1 score:  0.9667995572164563
# precision_score:  0.9382724027075492
# average_precision_score:  0.9283095357935394
# recall_score:  0.9971157807993407
# roc:  0.9616456894642079
# roc_weighted:  0.9633002538962511
#
#
# 70 80
# MAIN CLASSIFER
# Loan passing rate: 0.8231832011571649
# Balanced loan passing rate: 0.7990365384577551
#
#
# score:  0.9838562189302874
# balanced_accuracy_score:  0.956643438580742
# [[ 9706   929]
#  [   42 49470]]
# F1 score:  0.9902813504018577
# precision_score:  0.9815670945852101
# average_precision_score:  0.9787037735385511
# recall_score:  0.9991517207949588
# roc:  0.9948255538228
# roc_weighted:  0.9951658630697073
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8231832011571649
# Balanced loan passing rate: 0.7990365384577551
#
#
# score:  0.9470630289124977
# balanced_accuracy_score:  0.8518262415039017
# [[ 7539  3096]
#  [   88 49424]]
# F1 score:  0.9687941038105693
# precision_score:  0.9410510281797411
# average_precision_score:  0.9306944536064686
# recall_score:  0.9982226530941994
# roc:  0.9622451525573187
# roc_weighted:  0.9631022515326181
#
#
# 80 90
# MAIN CLASSIFER
# Loan passing rate: 0.8357135706897127
# Balanced loan passing rate: 0.8145621343890154
#
#
# score:  0.9851179552203944
# balanced_accuracy_score:  0.9560117695585062
# [[ 8985   862]
#  [   30 50061]]
# F1 score:  0.9911695408557231
# precision_score:  0.9830724819826012
# average_precision_score:  0.9803912452854238
# recall_score:  0.9994010900161706
# roc:  0.9957862472771375
# roc_weighted:  0.9958540140180121
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8357135706897127
# Balanced loan passing rate: 0.8145621343890154
#
#
# score:  0.9497313891020721
# balanced_accuracy_score:  0.8484546142849052
# [[ 6864  2983]
#  [   30 50061]]
# F1 score:  0.9707858631890242
# precision_score:  0.9437636678983485
# average_precision_score:  0.9354706954165817
# recall_score:  0.9994010900161706
# roc:  0.9623385996032969
# roc_weighted:  0.9634790201420689
#
#
# 90 100
# MAIN CLASSIFER
# Loan passing rate: 0.8501862911621281
# Balanced loan passing rate: 0.8368548543149998
#
#
# score:  0.9869870144101693
# balanced_accuracy_score:  0.9576700396202817
# [[ 9998   939]
#  [   11 62056]]
# F1 score:  0.9924037677312053
# precision_score:  0.9850940550837368
# average_precision_score:  0.9837681928589703
# recall_score:  0.999822772165563
# roc:  0.9953654450629739
# roc_weighted:  0.9954513099246108
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8501862911621281
# Balanced loan passing rate: 0.8368548543149998
#
#
# score:  0.9555366829214837
# balanced_accuracy_score:  0.853541260325647
# [[ 7727  3210]
#  [   36 62031]]
# F1 score:  0.9745027806579319
# precision_score:  0.9507978111923484
# average_precision_score:  0.945990808469716
# recall_score:  0.9994199816327517
# roc:  0.9639177655364713
# roc_weighted:  0.9636417975315626

# %% [markdown]
# The Global classifier has outperformed the locally trained version.

# %% [markdown]
# FICO test

# %%
for decile in [1,5,7,8,9,10]:
    print((decile-1)*10,decile*10)
    
    ml_test(df.loc[(df.fico_range_high > np.percentile(df.fico_range_high,(decile-1)*10)) & 
                   (df.fico_range_high<np.percentile(df.fico_range_high,decile*10))])
    print('\n')
# Out:
# 0 10
# MAIN CLASSIFER
# Loan passing rate: 0.7313474510264963
# Balanced loan passing rate: 0.6995969401756819
#
#
# score:  0.9770011903537261
# balanced_accuracy_score:  0.9605620588202005
# [[16872  1409]
#  [  156 49610]]
# F1 score:  0.9844718956193879
# precision_score:  0.9723828377663224
# average_precision_score:  0.9677030849263832
# recall_score:  0.9968653297431982
# roc:  0.9960251057164037
# roc_weighted:  0.9961777224487528
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7313474510264963
# Balanced loan passing rate: 0.6995969401756819
#
#
# score:  0.9215836113274648
# balanced_accuracy_score:  0.8642289477948322
# [[13467  4814]
#  [  522 49244]]
# F1 score:  0.9486053321004778
# precision_score:  0.9109475008324392
# average_precision_score:  0.896421246402596
# recall_score:  0.9895109110637785
# roc:  0.9648287907872715
# roc_weighted:  0.9648584215433926
#
#
# 40 50
# MAIN CLASSIFER
# Loan passing rate: 0.7851703564138798
# Balanced loan passing rate: 0.7650369482232141
#
#
# score:  0.9797260166431151
# balanced_accuracy_score:  0.9548772166292385
# [[ 9964   982]
#  [   51 39955]]
# F1 score:  0.987237932866338
# precision_score:  0.9760119207562841
# average_precision_score:  0.9731294245338823
# recall_score:  0.9987251912213168
# roc:  0.9957289797723471
# roc_weighted:  0.9957106096073404
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7851703564138798
# Balanced loan passing rate: 0.7650369482232141
#
#
# score:  0.9352724132516879
# balanced_accuracy_score:  0.8554651951290052
# [[ 7746  3200]
#  [   98 39908]]
# F1 score:  0.960319561084775
# precision_score:  0.9257678389162104
# average_precision_score:  0.9185653193540712
# recall_score:  0.9975503674448832
# roc:  0.9643959947210183
# roc_weighted:  0.9663236315894271
#
#
# 60 70
# MAIN CLASSIFER
# Loan passing rate: 0.8146754237079674
# Balanced loan passing rate: 0.8011586105286239
#
#
# score:  0.9832976656089342
# balanced_accuracy_score:  0.9567887296249806
# [[ 6871   663]
#  [   16 33103]]
# F1 score:  0.9898482469911041
# precision_score:  0.9803648640644436
# average_precision_score:  0.9790262700330791
# recall_score:  0.9995168936260153
# roc:  0.9949237861461409
# roc_weighted:  0.9948759114186745
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8146754237079674
# Balanced loan passing rate: 0.8011586105286239
#
#
# score:  0.9463754212481243
# balanced_accuracy_score:  0.8591215025127036
# [[ 5394  2140]
#  [   40 33079]]
# F1 score:  0.9680997395299833
# precision_score:  0.9392373434793719
# average_precision_score:  0.9346720335712801
# recall_score:  0.9987922340650381
# roc:  0.9615470907721625
# roc_weighted:  0.962249623260404
#
#
# 70 80
# MAIN CLASSIFER
# Loan passing rate: 0.8416479400749064
# Balanced loan passing rate: 0.8284318554066319
#
#
# score:  0.9855680399500624
# balanced_accuracy_score:  0.9555710951680767
# [[ 8658   855]
#  [   12 50550]]
# F1 score:  0.9914972491100063
# precision_score:  0.9833673767143274
# average_precision_score:  0.9819409743895449
# recall_score:  0.9997626676159962
# roc:  0.9949939147765513
# roc_weighted:  0.9951530612979334
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8416479400749064
# Balanced loan passing rate: 0.8284318554066319
#
#
# score:  0.9528256346233874
# balanced_accuracy_score:  0.8519981630768758
# [[ 6697  2816]
#  [   18 50544]]
# F1 score:  0.9727295471603704
# precision_score:  0.9472263868065967
# average_precision_score:  0.9422463294713926
# recall_score:  0.9996440014239943
# roc:  0.9598249783648026
# roc_weighted:  0.9611993525008836
#
#
# 80 90
# MAIN CLASSIFER
# Loan passing rate: 0.8697131745260087
# Balanced loan passing rate: 0.8589622865408598
#
#
# score:  0.9882717549829849
# balanced_accuracy_score:  0.9539470520698637
# [[ 5859   573]
#  [    6 42930]]
# F1 score:  0.9933016346787908
# precision_score:  0.9868284945865803
# average_precision_score:  0.9851048083325173
# recall_score:  0.9998602571268865
# roc:  0.9954982006511832
# roc_weighted:  0.9954415767063867
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8697131745260087
# Balanced loan passing rate: 0.8589622865408598
#
#
# score:  0.9613109706692594
# balanced_accuracy_score:  0.8501667623394018
# [[ 4534  1898]
#  [   12 42924]]
# F1 score:  0.9782356024521981
# precision_score:  0.9576547231270358
# average_precision_score:  0.9531069562401661
# recall_score:  0.9997205142537731
# roc:  0.9629118207117477
# roc_weighted:  0.9642401365843384
#
#
# 90 100
# MAIN CLASSIFER
# Loan passing rate: 0.9106408867652951
# Balanced loan passing rate: 0.897879558663348
#
#
# score:  0.9916012523927528
# balanced_accuracy_score:  0.9552175770087077
# [[ 5458   564]
#  [    2 61367]]
# F1 score:  0.9954095701540957
# precision_score:  0.9908930906977119
# average_precision_score:  0.9899167693079692
# recall_score:  0.9999674102559925
# roc:  0.9940927327798637
# roc_weighted:  0.9944496694780226
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.9106408867652951
# Balanced loan passing rate: 0.897879558663348
#
#
# score:  0.9727560059948658
# balanced_accuracy_score:  0.8499752910027428
# [[ 4190  1832]
#  [    4 61365]]
# F1 score:  0.985260825586436
# precision_score:  0.9710112821811162
# average_precision_score:  0.9670006656666102
# recall_score:  0.9999348205119849
# roc:  0.9620349181194047
# roc_weighted:  0.9641785485451829

# %%
feature_importance = pd.DataFrame(data = rf_best.feature_importances_,index=X.columns,columns=['feature_importance'])
feature_importance.sort_values(by='feature_importance',ascending =False)
# Out:
#                                            feature_importance
# int_rate                                             0.044692
# dti                                                  0.030237
# installment                                          0.026616
# annual_inc                                           0.024941
# length_of_cr                                         0.024522
# revol_util                                           0.024340
# revol_bal                                            0.024164
# bc_open_to_buy                                       0.023242
# avg_cur_bal                                          0.023225
# tot_hi_cred_lim                                      0.023047
# mo_sin_old_rev_tl_op                                 0.022069
# total_bc_limit                                       0.022053
# loan_amnt                                            0.022014
# bc_util                                              0.021915
# tot_cur_bal                                          0.021825
# total_rev_hi_lim                                     0.021532
# total_bal_ex_mort                                    0.021501
# mo_sin_old_il_acct                                   0.021260
# total_acc                                            0.019416
# total_il_high_credit_limit                           0.019286
# mths_since_recent_bc                                 0.018934
# term                                                 0.017879
# fico_range_high                                      0.017100
# fico_range_low                                       0.016917
# mo_sin_rcnt_rev_tl_op                                0.015892
# num_rev_accts                                        0.015675
# num_il_tl                                            0.015171
# mths_since_recent_inq                                0.015129
# mo_sin_rcnt_tl                                       0.014460
# open_acc                                             0.014224
# ...                                                       ...
# revol_bal_joint                                      0.000274
# delinq_amnt                                          0.000269
# sub_grade_F4                                         0.000258
# sec_length_of_cr                                     0.000251
# sec_app_num_rev_accts                                0.000243
# sec_app_fico_range_high                              0.000238
# sec_app_open_acc                                     0.000234
# sec_app_fico_range_low                               0.000230
# application_type                                     0.000227
# sub_grade_F5                                         0.000220
# acc_now_delinq                                       0.000209
# sec_app_open_act_il                                  0.000199
# sec_app_inq_last_6mths                               0.000157
# num_tl_30dpd                                         0.000154
# sub_grade_G1                                         0.000152
# purpose_wedding                                      0.000136
# sec_app_mths_since_last_major_derog                  0.000135
# sec_app_mort_acc                                     0.000118
# disbursement_method                                  0.000116
# sub_grade_G2                                         0.000114
# sub_grade_G3                                         0.000086
# purpose_renewable_energy                             0.000073
# sub_grade_G4                                         0.000068
# verification_status_joint_Source Verified            0.000066
# sub_grade_G5                                         0.000059
# verification_status_joint_Verified                   0.000047
# sec_app_collections_12_mths_ex_med                   0.000046
# purpose_educational                                  0.000039
# num_tl_120dpd_2m                                     0.000038
# sec_app_chargeoff_within_12_mths                     0.000019
#
# [146 rows x 1 columns]
