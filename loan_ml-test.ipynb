# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('lending_club_ml.csv')
df.drop(['id'], inplace=True, axis=1)

# %%
# creating columns for features that had more than 2 outcomes
# I have decided to use subgrade and not grade as these are suppose to be similar features but, subgrade is more granular

df = pd.concat([df, pd.get_dummies(
    df.sub_grade, prefix='sub_grade', drop_first=True)], axis=1)
df = pd.concat([df, pd.get_dummies(df.home_ownership,
                                   prefix='home_ownership', drop_first=True)], axis=1)
df = pd.concat([df, pd.get_dummies(df.verification_status,
                                   prefix='verification_status', drop_first=True)], axis=1)
df = pd.concat(
    [df, pd.get_dummies(df.purpose, prefix='purpose', drop_first=True)], axis=1)
df = pd.concat([df, pd.get_dummies(df.verification_status_joint,
                                   prefix='verification_status_joint', drop_first=True)], axis=1)

df.drop(columns=['sub_grade', 'home_ownership', 'verification_status',
                 'purpose', 'verification_status_joint'], inplace=True)


# conversions for features that only had 2 outcomes

df.disbursement_method = df.disbursement_method.apply(
    lambda disburstment: 1 if disburstment == 'Cash' else 0)

df.application_type = df.application_type.apply(
    lambda app_type: 1 if app_type == 'Individual' else 0)

# %%
# if borrower is an indivudal then their secondary features are filled with their single counterpart

sec_list = ['sec_app_fico_range_low', 'sec_app_fico_range_high', 'sec_app_inq_last_6mths', 'sec_app_mort_acc',
            'sec_app_open_acc', 'sec_app_revol_util', 'sec_app_open_act_il','sec_app_num_rev_accts', 'sec_app_chargeoff_within_12_mths',
            'sec_app_collections_12_mths_ex_med', 'sec_app_mths_since_last_major_derog']
joint_list = ['dti_joint', 'revol_bal_joint', 'annual_inc_joint']

for secondary in sec_list:
    df.loc[df.application_type == 1,secondary] = df.loc[df.application_type == 1][secondary[8:]]


for joint in joint_list:
    df.loc[df.application_type == 1,joint] = df.loc[df.application_type == 1][joint[:len(joint)-6]]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2506738 entries, 0 to 2506737
# Columns: 148 entries, loan_amnt to verification_status_joint_Verified
# dtypes: float64(89), int64(5), object(1), uint8(53)
# memory usage: 1.9+ GB

# %%
#fill all nans with 0
df.fillna(0, inplace=True)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score


def scoring(clf, x, y):
    
    #Baseline
    print('Loan passing rate:', np.mean(y))
    print('Balanced loan passing rate:', np.average(y, weights=x['loan_amnt']))
    print('\n')
    
    
    print('score: ', clf.score(x, y))
    # score adjusted for loan amount
    print('balanced_accuracy_score: ', balanced_accuracy_score(
        y, clf.predict(x), sample_weight=x['loan_amnt']))

    print(confusion_matrix(y, clf.predict(x)))
    
    print('F1 score: ', f1_score(y, clf.predict(x)))
    
    print('precision_score: ', precision_score(y, clf.predict(x)))

    # score adjusted for loan amount
    print('average_precision_score: ', average_precision_score(
        y, clf.predict(x), average='weighted', sample_weight=x['loan_amnt']))
    
    print('recall_score: ', recall_score(y, clf.predict(x)))

    print('roc: ', roc_auc_score(y, clf.predict_proba(x)[:, 1]))

    # score adjusted for loan amount
    print('roc_weighted: ', roc_auc_score(y, clf.predict_proba(x)[
          :, 1], average='weighted', sample_weight=x['loan_amnt']))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

X = df.drop(['grade','loan_status'], axis=1)
y = df.loan_status

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)



rf_best = RandomForestClassifier(criterion= 'entropy', n_estimators= 101)
rf_best.fit(X_train, y_train)
    
print('RANDOM FOREST')
scoring(rf_best, X_test, y_test)
# Out:
# RANDOM FOREST
# Loan passing rate: 0.8009672589365736
# Balanced loan passing rate: 0.7855872316459166
#
#
# score:  0.9414352239695115
# balanced_accuracy_score:  0.8598431799117082
# [[107995  41682]
#  [  2360 599985]]
# F1 score:  0.9645968045324322
# precision_score:  0.9350410727059363
# average_precision_score:  0.9290625875070259
# recall_score:  0.9960819795964106
# roc:  0.9645267462749104
# roc_weighted:  0.9655248162599434

# %% [markdown]
# # Testing based off of certain features
# Here will be testing our classifier, that was trained and test on the general populatyion with global averages to fill the nans, on certain sub-groups of the population and to see if we need to fill nans with local averages.

# %%
def ml_test(dataframe):
    dataframe.fillna(0,inplace=True)
    
    X = dataframe.drop(['grade','loan_status'], axis=1)
    y = dataframe.loan_status

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    
    print('MAIN CLASSIFER')
    scoring(rf_best, X_test, y_test)
    
    print('\n')
    print('RETRAINED CLASSIFER')
    rf = RandomForestClassifier(criterion= 'entropy', n_estimators= 101)
    rf.fit(X_train, y_train)
    scoring(rf, X_test, y_test)

# %% [markdown]
# Individual verse joint: in our EDA joint borrowers failed in higher rates and had wide differences between their single and joint/secondary features.

# %%
ml_test(df.loc[df.application_type == 1])
# Out:
# MAIN CLASSIFER
# Loan passing rate: 0.8018762389397847
# Balanced loan passing rate: 0.7866714294905874
#
#
# score:  0.9764619995492925
# balanced_accuracy_score:  0.9434088562562084
# [[130255  16566]
#  [   877 593359]]
# F1 score:  0.9855143955002694
# precision_score:  0.9728392835184654
# average_precision_score:  0.970302536186
# recall_score:  0.9985241553860755
# roc:  0.9923215332215768
# roc_weighted:  0.9926144177629965
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8018762389397847
# Balanced loan passing rate: 0.7866714294905874
#
#
# score:  0.9411435287703915
# balanced_accuracy_score:  0.859340311828035
# [[105697  41124]
#  [  2492 591744]]
# F1 score:  0.9644561504159387
# precision_score:  0.9350196249454863
# average_precision_score:  0.9292599632894468
# recall_score:  0.9958063799567849
# roc:  0.9638754274871868
# roc_weighted:  0.9646982666695247

# %%
ml_test(df.loc[df.application_type == 0])
# Out:
# MAIN CLASSIFER
# Loan passing rate: 0.7680802553579571
# Balanced loan passing rate: 0.7633904760778214
#
#
# score:  0.9794801641586868
# balanced_accuracy_score:  0.959861310398982
# [[2340  203]
#  [  22 8400]]
# F1 score:  0.9867841409691631
# precision_score:  0.9764035801464606
# average_precision_score:  0.9758982268463176
# recall_score:  0.9973877938731893
# roc:  0.9976604259036195
# roc_weighted:  0.9979079265676026
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7680802553579571
# Balanced loan passing rate: 0.7633904760778214
#
#
# score:  0.9252165982672138
# balanced_accuracy_score:  0.8408581350792388
# [[1763  780]
#  [  40 8382]]
# F1 score:  0.9533666969972703
# precision_score:  0.9148657498362803
# average_precision_score:  0.9103189532297549
# recall_score:  0.9952505343148895
# roc:  0.9641493315682679
# roc_weighted:  0.9639070734726592

# %% [markdown]
# The Global classifier has outperformed the locally trained version.

# %% [markdown]
# ML for different grades

# %%
grades = set(df.grade)

for loan_grade in sorted(grades):
    print(loan_grade)
    ml_test(df.loc[df.grade==loan_grade])
    print('\n')
# Out:
# A
# MAIN CLASSIFER
# Loan passing rate: 0.9405104807551982
# Balanced loan passing rate: 0.9413940416432522
#
#
# score:  0.9946232842515996
# balanced_accuracy_score:  0.9570392949224038
# [[  7045    700]
#  [     0 122446]]
# F1 score:  0.9971497442913451
# precision_score:  0.9943156903188086
# average_precision_score:  0.99467947023111
# recall_score:  1.0
# roc:  0.9925819902934617
# roc_weighted:  0.9927854720555352
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.9405104807551982
# Balanced loan passing rate: 0.9413940416432522
#
#
# score:  0.9826792942676529
# balanced_accuracy_score:  0.8520743593414324
# [[  5490   2255]
#  [     0 122446]]
# F1 score:  0.9908758754911045
# precision_score:  0.9819167448536901
# average_precision_score:  0.9819150342298049
# recall_score:  1.0
# roc:  0.9493045189169541
# roc_weighted:  0.9468541445837867
#
#
# B
# MAIN CLASSIFER
# Loan passing rate: 0.8673473571985074
# Balanced loan passing rate: 0.8650654540003315
#
#
# score:  0.9879626212508485
# balanced_accuracy_score:  0.9544581410331217
# [[ 26473   2642]
#  [     0 190368]]
# F1 score:  0.993108629081481
# precision_score:  0.9863115900730532
# average_precision_score:  0.9859916122858994
# recall_score:  1.0
# roc:  0.9949384654141461
# roc_weighted:  0.9949618209781246
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8673473571985074
# Balanced loan passing rate: 0.8650654540003315
#
#
# score:  0.9598966662566121
# balanced_accuracy_score:  0.8500392460286377
# [[ 20313   8802]
#  [     0 190368]]
# F1 score:  0.977404001663509
# precision_score:  0.9558065973791233
# average_precision_score:  0.9553084503782855
# recall_score:  1.0
# roc:  0.9565185042363207
# roc_weighted:  0.9577411139138398
#
#
# C
# MAIN CLASSIFER
# Loan passing rate: 0.7772935382135309
# Balanced loan passing rate: 0.7696991390065671
#
#
# score:  0.9801164986667792
# balanced_accuracy_score:  0.95553503615094
# [[ 43315   4209]
#  [    34 165835]]
# F1 score:  0.9873687532188394
# precision_score:  0.9752475829785232
# average_precision_score:  0.9740933785719371
# recall_score:  0.9997950189607462
# roc:  0.9958345412840155
# roc_weighted:  0.9959086689166807
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7772935382135309
# Balanced loan passing rate: 0.7696991390065671
#
#
# score:  0.9334748562511422
# balanced_accuracy_score:  0.8525664648751334
# [[ 33430  14094]
#  [   102 165767]]
# F1 score:  0.958939056489168
# precision_score:  0.9216394882714986
# average_precision_score:  0.9189471055254474
# recall_score:  0.9993850568822384
# roc:  0.9608995789189202
# roc_weighted:  0.9612407138674454
#
#
# D
# MAIN CLASSIFER
# Loan passing rate: 0.6985549107182656
# Balanced loan passing rate: 0.684318232759796
#
#
# score:  0.972899004216701
# balanced_accuracy_score:  0.9563858445850376
# [[30988  2826]
#  [  214 78145]]
# F1 score:  0.9809201029310237
# precision_score:  0.9650986155537168
# average_precision_score:  0.961660783522683
# recall_score:  0.99726897995125
# roc:  0.9964814879110276
# roc_weighted:  0.9965358349612341
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.6985549107182656
# Balanced loan passing rate: 0.684318232759796
#
#
# score:  0.9105845435176023
# balanced_accuracy_score:  0.8575475259551573
# [[24404  9410]
#  [  620 77739]]
# F1 score:  0.9393986997607366
# precision_score:  0.8920240048652308
# average_precision_score:  0.884333260547088
# recall_score:  0.9920876989241822
# roc:  0.9633754595553667
# roc_weighted:  0.9638147994745758
#
#
# E
# MAIN CLASSIFER
# Loan passing rate: 0.6156433188035473
# Balanced loan passing rate: 0.6043316083087944
#
#
# score:  0.9661055163084323
# balanced_accuracy_score:  0.9571177098918542
# [[18914  1543]
#  [  261 32506]]
# F1 score:  0.9730004789272031
# precision_score:  0.9546829569150342
# average_precision_score:  0.9484758194054819
# recall_score:  0.9920346690267647
# roc:  0.9966103941722916
# roc_weighted:  0.9964577339060171
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.6156433188035473
# Balanced loan passing rate: 0.6043316083087944
#
#
# score:  0.8897489854201113
# balanced_accuracy_score:  0.8638595833497319
# [[15651  4806]
#  [ 1062 31705]]
# F1 score:  0.9152977857328445
# precision_score:  0.8683684369094246
# average_precision_score:  0.8520610027752324
# recall_score:  0.967589342936491
# roc:  0.9642324023716993
# roc_weighted:  0.9632086227532789
#
#
# F
# MAIN CLASSIFER
# Loan passing rate: 0.549331012727075
# Balanced loan passing rate: 0.5378723846276439
#
#
# score:  0.9633960622212553
# balanced_accuracy_score:  0.9601798921662836
# [[7783  503]
#  [ 170 9930]]
# F1 score:  0.9672234938878879
# precision_score:  0.951787597047829
# average_precision_score:  0.9413938619905183
# recall_score:  0.9831683168316832
# roc:  0.9968399937386933
# roc_weighted:  0.9966551724679577
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.549331012727075
# Balanced loan passing rate: 0.5378723846276439
#
#
# score:  0.874034591537039
# balanced_accuracy_score:  0.8659168201294869
# [[6804 1482]
#  [ 834 9266]]
# F1 score:  0.8889102072141213
# precision_score:  0.8621138816524004
# average_precision_score:  0.8263931174302214
# recall_score:  0.9174257425742575
# roc:  0.9642149229405199
# roc_weighted:  0.9623293912574051
#
#
# G
# MAIN CLASSIFER
# Loan passing rate: 0.49284885968303055
# Balanced loan passing rate: 0.4956165657835817
#
#
# score:  0.9626981059141864
# balanced_accuracy_score:  0.9636290359884064
# [[2488  136]
#  [  57 2493]]
# F1 score:  0.9627341185557058
# precision_score:  0.9482693039178395
# average_precision_score:  0.9397748982638973
# recall_score:  0.9776470588235294
# roc:  0.9968936812529889
# roc_weighted:  0.9970495854401622
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.49284885968303055
# Balanced loan passing rate: 0.4956165657835817
#
#
# score:  0.8666408967916506
# balanced_accuracy_score:  0.863800757986493
# [[2272  352]
#  [ 338 2212]]
# F1 score:  0.8650762612436449
# precision_score:  0.8627145085803433
# average_precision_score:  0.8079473343738868
# recall_score:  0.8674509803921568
# roc:  0.9619826040172167
# roc_weighted:  0.9606182912654434

# %% [markdown]
# The Global classifier has outperformed the locally trained version.

# %% [markdown]
# ML for different loan sizes

# %%
for decile in np.arange(1,11):
    print((decile-1)*10,decile*10)
    
    ml_test(df.loc[(df.loan_amnt > np.percentile(df.loan_amnt,(decile-1)*10)) & 
                   (df.loan_amnt<np.percentile(df.loan_amnt,decile*10))])
    print('\n')
# Out:
# 0 10
# MAIN CLASSIFER
# Loan passing rate: 0.8456880009798451
# Balanced loan passing rate: 0.8423225500026952
#
#
# score:  0.9860780337774391
# balanced_accuracy_score:  0.9555555261758979
# [[10327  1012]
#  [   11 62131]]
# F1 score:  0.9918346170730735
# precision_score:  0.9839728869391698
# average_precision_score:  0.9836383730170525
# recall_score:  0.9998229860641756
# roc:  0.9951266216677824
# roc_weighted:  0.9950286540594365
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8456880009798451
# Balanced loan passing rate: 0.8423225500026952
#
#
# score:  0.9557164437065364
# balanced_accuracy_score:  0.8571636174459296
# [[ 8097  3242]
#  [   12 62130]]
# F1 score:  0.9744812334331917
# precision_score:  0.9504069020375696
# average_precision_score:  0.9492412293440604
# recall_score:  0.9998068938881916
# roc:  0.9631289248911601
# roc_weighted:  0.9631752551480401
#
#
# 10 20
# MAIN CLASSIFER
# Loan passing rate: 0.8402740327960533
# Balanced loan passing rate: 0.8404687232746312
#
#
# score:  0.9847005013282202
# balanced_accuracy_score:  0.9525429246507753
# [[ 7239   758]
#  [    8 42062]]
# F1 score:  0.9909765578984568
# precision_score:  0.9822979915927137
# average_precision_score:  0.9823074942873445
# recall_score:  0.9998098407416212
# roc:  0.9945793034046907
# roc_weighted:  0.9945779620366912
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8402740327960533
# Balanced loan passing rate: 0.8404687232746312
#
#
# score:  0.9512053847843889
# balanced_accuracy_score:  0.8489863436895696
# [[ 5586  2411]
#  [   32 42038]]
# F1 score:  0.9717634276864041
# precision_score:  0.9457580597988706
# average_precision_score:  0.9457895574511446
# recall_score:  0.9992393629664844
# roc:  0.9588996545204334
# roc_weighted:  0.9588171911047314
#
#
# 20 30
# MAIN CLASSIFER
# Loan passing rate: 0.8309950443577244
# Balanced loan passing rate: 0.8307076537011601
#
#
# score:  0.9847009735744089
# balanced_accuracy_score:  0.9550665079340985
# [[11395  1121]
#  [   12 61529]]
# F1 score:  0.9908769556570121
# precision_score:  0.9821069433359936
# average_precision_score:  0.982020517368604
# recall_score:  0.9998050080434182
# roc:  0.995003993886866
# roc_weighted:  0.9950046057593643
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8309950443577244
# Balanced loan passing rate: 0.8307076537011601
#
#
# score:  0.9492012908975519
# balanced_accuracy_score:  0.8510377338404362
# [[ 8794  3722]
#  [   40 61501]]
# F1 score:  0.9703228045817424
# precision_score:  0.9429342409886083
# average_precision_score:  0.9427700526957732
# recall_score:  0.9993500268113941
# roc:  0.9588340433937286
# roc_weighted:  0.9588085472625135
#
#
# 30 40
# MAIN CLASSIFER
# Loan passing rate: 0.8246477617264134
# Balanced loan passing rate: 0.8243078159533855
#
#
# score:  0.984769038701623
# balanced_accuracy_score:  0.9569650091283468
# [[ 4493   423]
#  [    4 23115]]
# F1 score:  0.9908481042501661
# precision_score:  0.9820290593933214
# average_precision_score:  0.9819909168041953
# recall_score:  0.9998269821359055
# roc:  0.9955860427587114
# roc_weighted:  0.9956121195548429
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8246477617264134
# Balanced loan passing rate: 0.8243078159533855
#
#
# score:  0.9459247369359729
# balanced_accuracy_score:  0.8475122275607113
# [[ 3420  1496]
#  [   20 23099]]
# F1 score:  0.9682273546548182
# precision_score:  0.939174628989632
# average_precision_score:  0.9389793444418724
# recall_score:  0.9991349106795276
# roc:  0.9553655176593484
# roc_weighted:  0.9554210616861168
#
#
# 40 50
# MAIN CLASSIFER
# Loan passing rate: 0.7700934579439253
# Balanced loan passing rate: 0.769898129472552
#
#
# score:  0.9806431173768414
# balanced_accuracy_score:  0.9603359432664115
# [[ 6696   561]
#  [   50 24258]]
# F1 score:  0.9875628473141042
# precision_score:  0.9773963495708933
# average_precision_score:  0.9769559896331672
# recall_score:  0.997943064011848
# roc:  0.9957858690464699
# roc_weighted:  0.9957916818991639
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7700934579439253
# Balanced loan passing rate: 0.769898129472552
#
#
# score:  0.9323934737842547
# balanced_accuracy_score:  0.861925067582574
# [[ 5313  1944]
#  [  190 24118]]
# F1 score:  0.9576335120111177
# precision_score:  0.9254086409331594
# average_precision_score:  0.924002593839377
# recall_score:  0.9921836432450222
# roc:  0.963616257523193
# roc_weighted:  0.9635722442137253
#
#
# 50 60
# MAIN CLASSIFER
# Loan passing rate: 0.7779965593715672
# Balanced loan passing rate: 0.7779150376575796
#
#
# score:  0.9796464028851535
# balanced_accuracy_score:  0.9568691552541202
# [[ 9810   901]
#  [   81 37455]]
# F1 score:  0.9870605597427923
# precision_score:  0.9765095421837522
# average_precision_score:  0.9760741713217012
# recall_score:  0.9978420716112532
# roc:  0.9958720585509252
# roc_weighted:  0.9958928388419215
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7779965593715672
# Balanced loan passing rate: 0.7779150376575796
#
#
# score:  0.9379028747901423
# balanced_accuracy_score:  0.8693819416989863
# [[ 7985  2726]
#  [  270 37266]]
# F1 score:  0.9613558972242287
# precision_score:  0.9318363672734546
# average_precision_score:  0.9308140021594756
# recall_score:  0.992806905370844
# roc:  0.9688647325418499
# roc_weighted:  0.9689817496043539
#
#
# 60 70
# MAIN CLASSIFER
# Loan passing rate: 0.7649989444796285
# Balanced loan passing rate: 0.7648301164890858
#
#
# score:  0.9798184504960946
# balanced_accuracy_score:  0.9599485778488615
# [[10270   862]
#  [   94 36144]]
# F1 score:  0.9869477363333515
# precision_score:  0.9767064800302654
# average_precision_score:  0.9761147419074387
# recall_score:  0.9974060378608091
# roc:  0.9963538216732487
# roc_weighted:  0.9963532645388814
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7649989444796285
# Balanced loan passing rate: 0.7648301164890858
#
#
# score:  0.9321089297023433
# balanced_accuracy_score:  0.8640453529505988
# [[ 8192  2940]
#  [  276 35962]]
# F1 score:  0.9571998935320735
# precision_score:  0.924425479409799
# average_precision_score:  0.9230948590887488
# recall_score:  0.992383685633865
# roc:  0.9665049118221241
# roc_weighted:  0.9664785412839513
#
#
# 70 80
# MAIN CLASSIFER
# Loan passing rate: 0.7735375221587552
# Balanced loan passing rate: 0.7739097135273253
#
#
# score:  0.9796467730286915
# balanced_accuracy_score:  0.9576138871490203
# [[12660  1137]
#  [  103 47024]]
# F1 score:  0.9869868189068929
# precision_score:  0.97639168621914
# average_precision_score:  0.9759478802850166
# recall_score:  0.9978144163642922
# roc:  0.9957860800922292
# roc_weighted:  0.9957738752452469
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7735375221587552
# Balanced loan passing rate: 0.7739097135273253
#
#
# score:  0.9336714595233405
# balanced_accuracy_score:  0.8645096665279101
# [[10188  3609]
#  [  432 46695]]
# F1 score:  0.9585244942574745
# precision_score:  0.9282562022900763
# average_precision_score:  0.9269200072679147
# recall_score:  0.9908332802851868
# roc:  0.9665452804191003
# roc_weighted:  0.9665641744296651
#
#
# 80 90
# MAIN CLASSIFER
# Loan passing rate: 0.7722949285584592
# Balanced loan passing rate: 0.7724105678601824
#
#
# score:  0.9791052697738732
# balanced_accuracy_score:  0.9571075861557073
# [[14938  1365]
#  [  131 55163]]
# F1 score:  0.9866215950349663
# precision_score:  0.9758526747806396
# average_precision_score:  0.9754716185319459
# recall_score:  0.9976308460230766
# roc:  0.995727492961786
# roc_weighted:  0.995730803158175
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7722949285584592
# Balanced loan passing rate: 0.7724105678601824
#
#
# score:  0.9335028003966647
# balanced_accuracy_score:  0.8625461299695059
# [[11938  4365]
#  [  396 54898]]
# F1 score:  0.95843990327959
# precision_score:  0.9263452744545501
# average_precision_score:  0.9252854093982545
# recall_score:  0.9928382826346439
# roc:  0.967536153278395
# roc_weighted:  0.9675056215446509
#
#
# 90 100
# MAIN CLASSIFER
# Loan passing rate: 0.7571632205262905
# Balanced loan passing rate: 0.7572959629998549
#
#
# score:  0.9786664958277944
# balanced_accuracy_score:  0.9574988368602941
# [[13890  1272]
#  [   60 47215]]
# F1 score:  0.9860905160710929
# precision_score:  0.9737661641264669
# average_precision_score:  0.9735590060983879
# recall_score:  0.9987308302485457
# roc:  0.9962605266262039
# roc_weighted:  0.9962836928099496
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7571632205262905
# Balanced loan passing rate: 0.7572959629998549
#
#
# score:  0.9282797059435911
# balanced_accuracy_score:  0.8597084720565134
# [[11012  4150]
#  [  328 46947]]
# F1 score:  0.954478916764933
# precision_score:  0.9187819245748282
# average_precision_score:  0.9177304435130244
# recall_score:  0.9930618720253834
# roc:  0.9637984939805051
# roc_weighted:  0.9638178604727806

# %% [markdown]
# The Global classifier has outperformed the locally trained version.

# %% [markdown]
# Annual Income by decile

# %%
for decile in np.arange(1,11):
    print((decile-1)*10,decile*10)
    
    ml_test(df.loc[(df.annual_inc > np.percentile(df.annual_inc,(decile-1)*10)) & 
                   (df.annual_inc<np.percentile(df.annual_inc,decile*10))])
    print('\n')
# Out:
# 0 10
# MAIN CLASSIFER
# Loan passing rate: 0.7586561440560218
# Balanced loan passing rate: 0.7413021730605859
#
#
# score:  0.9792558217084422
# balanced_accuracy_score:  0.958855475058197
# [[15939  1431]
#  [   62 54540]]
# F1 score:  0.9864976079151331
# precision_score:  0.9744331886155331
# average_precision_score:  0.9722167473149594
# recall_score:  0.9988645104574924
# roc:  0.9960201573380635
# roc_weighted:  0.9961609692378186
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7586561440560218
# Balanced loan passing rate: 0.7413021730605859
#
#
# score:  0.9295281498360474
# balanced_accuracy_score:  0.8636877101183926
# [[12620  4750]
#  [  322 54280]]
# F1 score:  0.9553646860039426
# precision_score:  0.919532441131628
# average_precision_score:  0.913466733758933
# recall_score:  0.9941027801179444
# roc:  0.9634190605058172
# roc_weighted:  0.964062997825472
#
#
# 10 20
# MAIN CLASSIFER
# Loan passing rate: 0.7724567494238119
# Balanced loan passing rate: 0.7475995478751546
#
#
# score:  0.9813869358461942
# balanced_accuracy_score:  0.9622350046597332
# [[14398  1201]
#  [   75 52880]]
# F1 score:  0.9880787772338279
# precision_score:  0.9777925704036537
# average_precision_score:  0.9752784456735235
# recall_score:  0.998583703144179
# roc:  0.9958695908647451
# roc_weighted:  0.995988842794577
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7724567494238119
# Balanced loan passing rate: 0.7475995478751546
#
#
# score:  0.9330746564751874
# balanced_accuracy_score:  0.8608586140419172
# [[11321  4278]
#  [  310 52645]]
# F1 score:  0.9582445985547606
# precision_score:  0.9248458443862762
# average_precision_score:  0.9144469391250503
# recall_score:  0.99414597299594
# roc:  0.9644922910953361
# roc_weighted:  0.9649337514592604
#
#
# 20 30
# MAIN CLASSIFER
# Loan passing rate: 0.7794971907437387
# Balanced loan passing rate: 0.7529445475413961
#
#
# score:  0.9796844744944926
# balanced_accuracy_score:  0.9577510556523265
# [[12721  1172]
#  [  108 49005]]
# F1 score:  0.9871084701379798
# precision_score:  0.97664268489547
# average_precision_score:  0.9732252832692565
# recall_score:  0.9978009895547004
# roc:  0.9955392906833167
# roc_weighted:  0.99566472111472
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7794971907437387
# Balanced loan passing rate: 0.7529445475413961
#
#
# score:  0.9352760054597975
# balanced_accuracy_score:  0.8641911115614644
# [[10119  3774]
#  [  304 48809]]
# F1 score:  0.959900094398993
# precision_score:  0.9282277542171424
# average_precision_score:  0.9185124176525266
# recall_score:  0.9938101928206381
# roc:  0.9654718190221631
# roc_weighted:  0.9664140380418644
#
#
# 30 40
# MAIN CLASSIFER
# Loan passing rate: 0.7870192307692307
# Balanced loan passing rate: 0.7608144134839486
#
#
# score:  0.9816277472527473
# balanced_accuracy_score:  0.9594782279399803
# [[11399  1005]
#  [   65 45771]]
# F1 score:  0.9884464216300263
# precision_score:  0.97851462288353
# average_precision_score:  0.9752802271255788
# recall_score:  0.9985819006894144
# roc:  0.9955781643971684
# roc_weighted:  0.9958017290310418
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7870192307692307
# Balanced loan passing rate: 0.7608144134839486
#
#
# score:  0.9382898351648352
# balanced_accuracy_score:  0.866373109380008
# [[ 9030  3374]
#  [  220 45616]]
# F1 score:  0.9620990023833127
# precision_score:  0.931128801796285
# average_precision_score:  0.9227245291411714
# recall_score:  0.9952002792564796
# roc:  0.9635934125053445
# roc_weighted:  0.9656980331842007
#
#
# 40 50
# MAIN CLASSIFER
# Loan passing rate: 0.7948102021144754
# Balanced loan passing rate: 0.7663497548369754
#
#
# score:  0.981440964519041
# balanced_accuracy_score:  0.9571641202425619
# [[12270  1141]
#  [   72 51876]]
# F1 score:  0.9884437669699423
# precision_score:  0.9784786012033876
# average_precision_score:  0.9746665201058654
# recall_score:  0.9986139986139986
# roc:  0.9950443953873974
# roc_weighted:  0.9954669139632892
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7948102021144754
# Balanced loan passing rate: 0.7663497548369754
#
#
# score:  0.9402989641824385
# balanced_accuracy_score:  0.8617227954258829
# [[ 9661  3750]
#  [  152 51796]]
# F1 score:  0.9637002995516029
# precision_score:  0.9324883880027365
# average_precision_score:  0.9223738300584354
# recall_score:  0.997073997073997
# roc:  0.9644746858787572
# roc_weighted:  0.965994585895829
#
#
# 50 60
# MAIN CLASSIFER
# Loan passing rate: 0.8040294590705155
# Balanced loan passing rate: 0.7763055367479574
#
#
# score:  0.9831541522051976
# balanced_accuracy_score:  0.9591570564836814
# [[10638   937]
#  [   58 47432]]
# F1 score:  0.9896201712932536
# precision_score:  0.9806280882383345
# average_precision_score:  0.9770914111642283
# recall_score:  0.9987786902505791
# roc:  0.9959795987514934
# roc_weighted:  0.9959153028246285
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8040294590705155
# Balanced loan passing rate: 0.7763055367479574
#
#
# score:  0.9415220519766359
# balanced_accuracy_score:  0.8583875056167173
# [[ 8269  3306]
#  [  148 47342]]
# F1 score:  0.9648046628217407
# precision_score:  0.9347259516664034
# average_precision_score:  0.9246835758828164
# recall_score:  0.9968835544325121
# roc:  0.9645947533799317
# roc_weighted:  0.9649091599323782
#
#
# 60 70
# MAIN CLASSIFER
# Loan passing rate: 0.8117283090387134
# Balanced loan passing rate: 0.7845664394150497
#
#
# score:  0.9832353187101089
# balanced_accuracy_score:  0.9577450152967368
# [[12366  1144]
#  [   59 58189]]
# F1 score:  0.9897687551560201
# precision_score:  0.9807189928033303
# average_precision_score:  0.9773934112539758
# recall_score:  0.9989870896854828
# roc:  0.9954096936237621
# roc_weighted:  0.995777075794888
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8117283090387134
# Balanced loan passing rate: 0.7845664394150497
#
#
# score:  0.9446751581705176
# balanced_accuracy_score:  0.8596539327825001
# [[ 9702  3808]
#  [  162 58086]]
# F1 score:  0.9669557690066755
# precision_score:  0.9384754580411672
# average_precision_score:  0.9285527970013496
# recall_score:  0.9972187886279357
# roc:  0.9631217283641116
# roc_weighted:  0.9637383145755918
#
#
# 70 80
# MAIN CLASSIFER
# Loan passing rate: 0.8231832011571649
# Balanced loan passing rate: 0.7990365384577551
#
#
# score:  0.984039104194723
# balanced_accuracy_score:  0.9569119128063114
# [[ 9709   926]
#  [   34 49478]]
# F1 score:  0.9903919292205452
# precision_score:  0.981628442187128
# average_precision_score:  0.9788230282198321
# recall_score:  0.9993132977863952
# roc:  0.9944757267223351
# roc_weighted:  0.9948769132718066
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8231832011571649
# Balanced loan passing rate: 0.7990365384577551
#
#
# score:  0.9467970139824098
# balanced_accuracy_score:  0.8507100782739014
# [[ 7517  3118]
#  [   82 49430]]
# F1 score:  0.9686458945718206
# precision_score:  0.9406637740732283
# average_precision_score:  0.9302035877684384
# recall_score:  0.9983438358377767
# roc:  0.962379389840613
# roc_weighted:  0.9630985770887772
#
#
# 80 90
# MAIN CLASSIFER
# Loan passing rate: 0.8357135706897127
# Balanced loan passing rate: 0.8145621343890154
#
#
# score:  0.9849511161533585
# balanced_accuracy_score:  0.9554624915822132
# [[ 8973   874]
#  [   28 50063]]
# F1 score:  0.9910717820802154
# precision_score:  0.9828415493649018
# average_precision_score:  0.9801502743613598
# recall_score:  0.9994410173484258
# roc:  0.9955715795789288
# roc_weighted:  0.9957347513863883
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8357135706897127
# Balanced loan passing rate: 0.8145621343890154
#
#
# score:  0.9497981247288865
# balanced_accuracy_score:  0.8492575789744756
# [[ 6888  2959]
#  [   50 50041]]
# F1 score:  0.9708121950509744
# precision_score:  0.9441698113207547
# average_precision_score:  0.9358028476118424
# recall_score:  0.9990018166936177
# roc:  0.963248354431413
# roc_weighted:  0.9637315596932922
#
#
# 90 100
# MAIN CLASSIFER
# Loan passing rate: 0.8501862911621281
# Balanced loan passing rate: 0.8368548543149998
#
#
# score:  0.9870281080488741
# balanced_accuracy_score:  0.9577755507251107
# [[ 9998   939]
#  [    8 62059]]
# F1 score:  0.9924279374725142
# precision_score:  0.9850947649131718
# average_precision_score:  0.983806866130372
# recall_score:  0.9998711070295003
# roc:  0.9955640693721071
# roc_weighted:  0.9956436220990585
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8501862911621281
# Balanced loan passing rate: 0.8368548543149998
#
#
# score:  0.9556188701988932
# balanced_accuracy_score:  0.8543390116890248
# [[ 7745  3192]
#  [   48 62019]]
# F1 score:  0.9745439117522274
# precision_score:  0.9510512030178958
# average_precision_score:  0.9462743136603855
# recall_score:  0.9992266421770023
# roc:  0.9633799611785794
# roc_weighted:  0.9637493171227729

# %% [markdown]
# The Global classifier has outperformed the locally trained version.

# %% [markdown]
# FICO test

# %%
for decile in [1,5,7,8,9,10]:
    print((decile-1)*10,decile*10)
    
    ml_test(df.loc[(df.fico_range_high > np.percentile(df.fico_range_high,(decile-1)*10)) & 
                   (df.fico_range_high<np.percentile(df.fico_range_high,decile*10))])
    print('\n')
# Out:
# 0 10
# MAIN CLASSIFER
# Loan passing rate: 0.7313474510264963
# Balanced loan passing rate: 0.6995969401756819
#
#
# score:  0.9770452775287669
# balanced_accuracy_score:  0.9607875858980901
# [[16876  1405]
#  [  157 49609]]
# F1 score:  0.9845008930343323
# precision_score:  0.9724585407927235
# average_precision_score:  0.9678904406579448
# recall_score:  0.9968452357030905
# roc:  0.9959539406525267
# roc_weighted:  0.996121580018337
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7313474510264963
# Balanced loan passing rate: 0.6995969401756819
#
#
# score:  0.9214954369773832
# balanced_accuracy_score:  0.8635337652527894
# [[13473  4808]
#  [  534 49232]]
# F1 score:  0.9485386201182976
# precision_score:  0.9110288675055515
# average_precision_score:  0.8959622587148913
# recall_score:  0.989269782582486
# roc:  0.964851795445956
# roc_weighted:  0.9654961335905506
#
#
# 40 50
# MAIN CLASSIFER
# Loan passing rate: 0.7851703564138798
# Balanced loan passing rate: 0.7650369482232141
#
#
# score:  0.9797848955880044
# balanced_accuracy_score:  0.9546964802271096
# [[ 9960   986]
#  [   44 39962]]
# F1 score:  0.9872767250537342
# precision_score:  0.9759206798866855
# average_precision_score:  0.973012595015525
# recall_score:  0.9989001649752537
# roc:  0.9955291353656718
# roc_weighted:  0.9953667745491184
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.7851703564138798
# Balanced loan passing rate: 0.7650369482232141
#
#
# score:  0.9345658659130162
# balanced_accuracy_score:  0.8533658428490524
# [[ 7720  3226]
#  [  108 39898]]
# F1 score:  0.959894141705762
# precision_score:  0.9251924682311474
# average_precision_score:  0.9174856112600388
# recall_score:  0.9973004049392591
# roc:  0.9641186747257416
# roc_weighted:  0.9658946019168421
#
#
# 60 70
# MAIN CLASSIFER
# Loan passing rate: 0.8146754237079674
# Balanced loan passing rate: 0.8011586105286239
#
#
# score:  0.9832238703170738
# balanced_accuracy_score:  0.9571586040331865
# [[ 6876   658]
#  [   24 33095]]
# F1 score:  0.9898014116521114
# precision_score:  0.9805054365537879
# average_precision_score:  0.9792136004097114
# recall_score:  0.9992753404390229
# roc:  0.9954788931801486
# roc_weighted:  0.9956588025383575
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8146754237079674
# Balanced loan passing rate: 0.8011586105286239
#
#
# score:  0.9458834526357218
# balanced_accuracy_score:  0.8589613268738601
# [[ 5392  2142]
#  [   58 33061]]
# F1 score:  0.9677995374842657
# precision_score:  0.9391529131039968
# average_precision_score:  0.9346154059336852
# recall_score:  0.9982487393943054
# roc:  0.9619214156530073
# roc_weighted:  0.9621070595775906
#
#
# 70 80
# MAIN CLASSIFER
# Loan passing rate: 0.8416479400749064
# Balanced loan passing rate: 0.8284318554066319
#
#
# score:  0.9855014565126925
# balanced_accuracy_score:  0.9553622396706591
# [[ 8655   858]
#  [   13 50549]]
# F1 score:  0.9914581882729064
# precision_score:  0.983309665998794
# average_precision_score:  0.9818578151663899
# recall_score:  0.9997428899173292
# roc:  0.9946905850042016
# roc_weighted:  0.9950275489470799
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8416479400749064
# Balanced loan passing rate: 0.8284318554066319
#
#
# score:  0.9528422804827299
# balanced_accuracy_score:  0.8528365498751385
# [[ 6714  2799]
#  [   34 50528]]
# F1 score:  0.9727305104486519
# precision_score:  0.9475125171114069
# average_precision_score:  0.9425590809994763
# recall_score:  0.9993275582453226
# roc:  0.9598969477324844
# roc_weighted:  0.961469209706089
#
#
# 80 90
# MAIN CLASSIFER
# Loan passing rate: 0.8697131745260087
# Balanced loan passing rate: 0.8589622865408598
#
#
# score:  0.9883122670555826
# balanced_accuracy_score:  0.9537087490486225
# [[ 5857   575]
#  [    2 42934]]
# F1 score:  0.9933252356989993
# precision_score:  0.9867843434691673
# average_precision_score:  0.9850266543605201
# recall_score:  0.9999534190422955
# roc:  0.9954265313721592
# roc_weighted:  0.995317124512831
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.8697131745260087
# Balanced loan passing rate: 0.8589622865408598
#
#
# score:  0.9614325068870524
# balanced_accuracy_score:  0.8504829416617854
# [[ 4536  1896]
#  [    8 42928]]
# F1 score:  0.9783044667274384
# precision_score:  0.957701231483134
# average_precision_score:  0.95320073196754
# recall_score:  0.999813676169182
# roc:  0.9629142214560698
# roc_weighted:  0.9650883183727359
#
#
# 90 100
# MAIN CLASSIFER
# Loan passing rate: 0.9106408867652951
# Balanced loan passing rate: 0.897879558663348
#
#
# score:  0.9915715748393702
# balanced_accuracy_score:  0.9553014776226398
# [[ 5458   564]
#  [    4 61365]]
# F1 score:  0.9953932748300864
# precision_score:  0.990892796589643
# average_precision_score:  0.9899359939641514
# recall_score:  0.9999348205119849
# roc:  0.9942222962241156
# roc_weighted:  0.9943605931482391
#
#
# RETRAINED CLASSIFER
# Loan passing rate: 0.9106408867652951
# Balanced loan passing rate: 0.897879558663348
#
#
# score:  0.9728450386550133
# balanced_accuracy_score:  0.8501311510052748
# [[ 4194  1828]
#  [    2 61367]]
# F1 score:  0.9853087569442215
# precision_score:  0.9710736608908933
# average_precision_score:  0.9670335634215733
# recall_score:  0.9999674102559925
# roc:  0.9628194666885923
# roc_weighted:  0.9641326021062064

# %%
feature_importance_dictionary = {}

for column,feature_importance in zip(df.columns,rf_best.feature_importances_):
    feature_importance_dictionary[column] = feature_importance

# %%
for thing in sorted(feature_importance_dictionary, key=feature_importance_dictionary.get, reverse=True):
    print(thing,feature_importance_dictionary[thing])
# Out:
# int_rate 0.043631874229616924
# application_type 0.023902299694057744
# annual_inc 0.023795039759499877
# installment 0.02363722648086302
# disbursement_method 0.021282143861930565
# inq_last_12m 0.020076467029538053
# acc_open_past_24mths 0.019998085016663423
# loan_amnt 0.019890442928423627
# pub_rec_bankruptcies 0.01974179949019202
# open_acc 0.019676894717240156
# total_bc_limit 0.019644628870681278
# pub_rec 0.019591831461196894
# sec_app_mort_acc 0.019540944260989675
# mths_since_last_major_derog 0.019372685171678946
# delinq_amnt 0.019282761214607265
# emp_length 0.019162267904128588
# acc_now_delinq 0.01895624075292583
# tot_hi_cred_lim 0.018818092207064624
# avg_cur_bal 0.018814037833448503
# chargeoff_within_12_mths 0.018761256357897948
# tax_liens 0.018563439722250503
# max_bal_bc 0.018223982754868404
# total_bal_ex_mort 0.016669440757676974
# mo_sin_rcnt_tl 0.01655493129375922
# revol_bal 0.016354467609255515
# term 0.015534353779906399
# mo_sin_old_il_acct 0.013954336117730181
# num_bc_sats 0.013183840965204679
# mths_since_recent_bc 0.01306647976069482
# mo_sin_old_rev_tl_op 0.012664253657370502
# num_il_tl 0.012642446697352337
# sec_app_revol_util 0.012571135985539455
# total_cu_tl 0.012467107213403229
# revol_bal_joint 0.012106566505581128
# num_actv_rev_tl 0.011962750992188529
# grade 0.011668230406209646
# dti 0.011628118143625472
# sec_app_inq_last_6mths 0.0113111046215533
# mths_since_last_delinq 0.011212149067563286
# delinq_2yrs 0.011198195964470834
# total_il_high_credit_limit 0.011077871873613011
# fico_range_high 0.01094434490726126
# num_rev_accts 0.010390924257283322
# num_tl_90g_dpd_24m 0.010390896747397935
# num_bc_tl 0.010143338113095994
# num_tl_op_past_12m 0.009998994031902027
# num_op_rev_tl 0.009516753363815836
# num_actv_bc_tl 0.009489049483145915
# num_accts_ever_120_pd 0.009466312261820448
# mths_since_recent_revol_delinq 0.008477005897396967
# num_tl_30dpd 0.008299671782767321
# open_rv_12m 0.007830152217331682
# mths_since_recent_bc_dlq 0.007801970837073017
# open_rv_24m 0.007788614425422024
# mo_sin_rcnt_rev_tl_op 0.006536540932780459
# open_il_12m 0.006534706388729167
# open_il_24m 0.006447989471874189
# sec_app_fico_range_high 0.006435347671764899
# mths_since_rcnt_il 0.006229112829602324
# total_acc 0.006153891836805728
# sec_app_chargeoff_within_12_mths 0.006133667746924932
# mort_acc 0.006079024562042591
# inq_last_6mths 0.00550770477873691
# sec_app_fico_range_low 0.005492165486001728
# fico_range_low 0.005314723041111649
# dti_joint 0.005107883236689368
# il_util 0.004447756024981288
# inq_fi 0.004097736166310076
# mths_since_recent_inq 0.0036677810719316674
# loan_status 0.0036263469258102092
# sec_app_open_acc 0.003226164682993289
# tot_cur_bal 0.0031955759798955436
# total_rev_hi_lim 0.00314425117986407
# sub_grade_G5 0.003005325158594527
# open_act_il 0.0029518624586547756
# verification_status_Verified 0.0029307402235610133
# home_ownership_RENT 0.002930535159349883
# home_ownership_OWN 0.002928811030298497
# all_util 0.00288875168828352
# total_bal_il 0.002809293637015896
# tot_coll_amt 0.0024814012031863985
# mths_since_last_record 0.00247727269630401
# verification_status_Source Verified 0.00236826280401035
# open_acc_6m 0.001895452518529204
# pct_tl_nvr_dlq 0.0017825294907285758
# sub_grade_G4 0.0017763795413244224
# num_tl_120dpd_2m 0.0013745094925817567
# sub_grade_B4 0.0013388666064383732
# purpose_medical 0.0013207670517334032
# sub_grade_B5 0.0012631397124207063
# sub_grade_C2 0.0012629155096038646
# purpose_debt_consolidation 0.0012188830926933459
# sub_grade_C1 0.0012164637709580707
# sub_grade_A2 0.001207176169816516
# sub_grade_B2 0.0012003579026207028
# sub_grade_C3 0.0011951963632704451
# sub_grade_B3 0.0011804628770211362
# sub_grade_A3 0.0011716993125594816
# sub_grade_B1 0.0011602503079101935
# percent_bc_gt_75 0.0011301028142661242
# sub_grade_A5 0.0010642083357204739
# sub_grade_C4 0.0010454491879503063
# sub_grade_C5 0.001007701880760331
# sub_grade_A4 0.0009795974653014565
# sub_grade_D1 0.0008987371199958724
# sub_grade_D2 0.0008617664367257141
# length_of_cr 0.0008537489749348243
# purpose_other 0.0008205759520217497
# sub_grade_D3 0.0007811069672828907
# sec_length_of_cr 0.0007497377927719764
# sub_grade_D4 0.0007491183368310213
# sub_grade_D5 0.0007052942777435937
# purpose_home_improvement 0.0006890121981338367
# sub_grade_E1 0.0006549070960108585
# sec_app_num_rev_accts 0.0005855638389997403
# sub_grade_E2 0.0005706581057148127
# revol_util 0.0005607569040498055
# sub_grade_E3 0.000549864011013945
# purpose_house 0.0005064693651226515
# sub_grade_E4 0.0004076358759400913
# purpose_major_purchase 0.00036038056676759985
# sub_grade_E5 0.00032360813739275236
# sec_app_mths_since_last_major_derog 0.00031026402581111836
# purpose_renewable_energy 0.0003052239114668386
# sec_app_open_act_il 0.00028249527905850364
# bc_open_to_buy 0.000264842349856143
# sub_grade_F1 0.00025598671515000805
# purpose_educational 0.00024339487238230132
# bc_util 0.0002326968895020521
# sub_grade_F2 0.00022699927668593336
# collections_12_mths_ex_med 0.00020390268561286176
# sub_grade_F3 0.0001834417892573309
# annual_inc_joint 0.0001831698069887059
# num_sats 0.00014079256056098716
# sub_grade_F4 0.000127462878742652
# purpose_small_business 0.00010343939755544662
# sub_grade_F5 9.472799297674925e-05
# sec_app_collections_12_mths_ex_med 9.283946902010191e-05
# purpose_vacation 7.674530463152076e-05
# sub_grade_G1 7.32422367648617e-05
# purpose_moving 6.480873531973469e-05
# purpose_wedding 6.105979348686031e-05
# sub_grade_G2 5.649358131917803e-05
# sub_grade_G3 4.891150684859536e-05
# num_rev_tl_bal_gt_0 3.307955872248494e-05
# purpose_credit_card 3.205048833133647e-05
